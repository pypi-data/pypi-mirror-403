# %%
import sys

# %%
sys.path.append("../../../")
import phitter

# %%
def get_data(path: str) -> list[float | int]:
    sample_distribution_file = open(path, "r")
    data = [float(x.replace(",", ".")) for x in sample_distribution_file.read().splitlines()]
    sample_distribution_file.close()
    return data

# %%
path = "../../../distributions_samples/continuous_distributions_sample/sample_beta.txt"
data = get_data(path)

# %%
phi = phitter.Phitter(data=data)
phi.fit(n_workers=1)

# %%
phi.best_distribution
# Out:
# {'id': 'generalized_gamma',
#  'parameters': {'a': 805.3155402807893,
#   'd': 86.99775474112674,
#   'p': 16.75970079726325}}

# %%
phi.sorted_distributions
# Out:
# {'generalized_gamma': {'chi_square': {'test_statistic': 14.699283826576123,
#    'critical_value': 22.362032494826934,
#    'p_value': 0.3265001018036413,
#    'rejected': False},
#   'kolmogorov_smirnov': {'test_statistic': 0.01163848133608436,
#    'critical_value': 0.02915677208094496,
#    'p_value': 0.9285320022445024,
#    'rejected': False},
#   'anderson_darling': {'test_statistic': 0.20851897105649186,
#    'critical_value': 2.4923268305268924,
#    'p_value': 0.987908970578445,
#    'rejected': False},
#   'aic': 4321.73038217574,
#   'bic': 4338.761193613193,
#   'sse': 5.444327123897858,
#   'parameters': {'a': 805.3155402807893,
#    'd': 86.99775474112674,
#    'p': 16.75970079726325},
#   'n_test_passed': 3,
#   'n_test_null': 0},
#  'loggamma': {'chi_square': {'test_statistic': 14.701357421346264,
#    'critical_value': 22.362032494826934,
#    'p_value': 0.3263655241863683,
#    'rejected': False},
#   'kolmogorov_smirnov': {'test_statistic': 0.011717515199629047,
# ...

# %%
phi.summarize()
# Out:
#              distribution           aic           bic  \
# 0       generalized_gamma   4321.730382   4338.761194
# 1                loggamma  19823.770295  19840.801106
# 2              weibull_3p  19827.109093  19844.139905
# 3              johnson_sb  19826.106562  19848.814311
# 4   non_central_t_student  19826.601197  19849.308945
# 5              johnson_su  19829.806869  19852.514618
# 6                    burr  19840.645429  19857.676240
# 7                 burr_4p  19839.767215  19862.474964
# 8             kumaraswamy  19834.733155  19857.440903
# 9                    beta  19835.989278  19858.697027
# 10               dagum_4p  19850.327585  19873.035333
# 11            half_normal  19063.778809  19075.132683
# 12                 normal  19870.210078  19881.563952
# 13                   rice  19870.215580  19881.569454
# 14     generalized_normal  19870.465534  19887.496345
# 15           t_student_3p  19872.208808  19889.239620
# ...

# %%
phi.summarize_info()
# Out:
#             distribution           aic           bic  \
# 0      generalized_gamma   4321.730382   4338.761194
# 1               loggamma  19823.770295  19840.801106
# 2             weibull_3p  19827.109093  19844.139905
# 3             johnson_sb  19826.106562  19848.814311
# 4  non_central_t_student  19826.601197  19849.308945
# 5             johnson_su  19829.806869  19852.514618
# 6                   burr  19840.645429  19857.676240
# 7                burr_4p  19839.767215  19862.474964
# 8            kumaraswamy  19834.733155  19857.440903
# 9                   beta  19835.989278  19858.697027
#
#                                           parameters chi_square  \
# 0  {'a': 805.3155402807893, 'd': 86.9977547411267...      False
# 1  {'c': 7.790685521997519, 'mu': 753.86255471431...      False
# 2  {'alpha': 5.963385914534535, 'loc': 759.627239...      False
# 3  {'xi': -161.32891731800058, 'lambda': 1213.577...      False
# ...

# %%
phi.df_not_rejected_distributions
# Out:
#              distribution           aic           bic  \
#
# 0       generalized_gamma   4321.730382   4338.761194
# 1                loggamma  19823.770295  19840.801106
# 2              weibull_3p  19827.109093  19844.139905
# 3              johnson_sb  19826.106562  19848.814311
# 4   non_central_t_student  19826.601197  19849.308945
# 5              johnson_su  19829.806869  19852.514618
# 6                    burr  19840.645429  19857.676240
# 7                 burr_4p  19839.767215  19862.474964
# 8             kumaraswamy  19834.733155  19857.440903
# 9                    beta  19835.989278  19858.697027
# 10               dagum_4p  19850.327585  19873.035333
#
#                                            parameters     chi_square  \
#                                                       test_statistic
# 0                           a: 805.3, d: 87, p: 16.76      14.699284
# 1                   c: 7.791, mu: 753.9, sigma: 65.25      14.701357
# ...

# %%
phi.df_sorted_distributions.head(10)
# Out:
#             distribution passed           aic           bic  \
#
# 0      generalized_gamma      ✅   4321.730382   4338.761194
# 1               loggamma      ✅  19823.770295  19840.801106
# 2             weibull_3p      ✅  19827.109093  19844.139905
# 3             johnson_sb      ✅  19826.106562  19848.814311
# 4  non_central_t_student      ✅  19826.601197  19849.308945
# 5             johnson_su      ✅  19829.806869  19852.514618
# 6                   burr      ✅  19840.645429  19857.676240
# 7                burr_4p      ✅  19839.767215  19862.474964
# 8            kumaraswamy      ✅  19834.733155  19857.440903
# 9                   beta      ✅  19835.989278  19858.697027
#
#                                           parameters     chi_square  \
#                                                      test_statistic
# 0                          a: 805.3, d: 87, p: 16.76      14.699284
# 1                  c: 7.791, mu: 753.9, sigma: 65.25      14.701357
# ...

# %%
phi.sorted_distributions
# Out:
# {'generalized_gamma': {'chi_square': {'test_statistic': 14.699283826576123,
#    'critical_value': 22.362032494826934,
#    'p_value': 0.3265001018036413,
#    'rejected': False},
#   'kolmogorov_smirnov': {'test_statistic': 0.01163848133608436,
#    'critical_value': 0.02915677208094496,
#    'p_value': 0.9285320022445024,
#    'rejected': False},
#   'anderson_darling': {'test_statistic': 0.20851897105649186,
#    'critical_value': 2.4923268305268924,
#    'p_value': 0.987908970578445,
#    'rejected': False},
#   'aic': 4321.73038217574,
#   'bic': 4338.761193613193,
#   'sse': 5.444327123897858,
#   'parameters': {'a': 805.3155402807893,
#    'd': 86.99775474112674,
#    'p': 16.75970079726325},
#   'n_test_passed': 3,
#   'n_test_null': 0},
#  'loggamma': {'chi_square': {'test_statistic': 14.701357421346264,
#    'critical_value': 22.362032494826934,
#    'p_value': 0.3263655241863683,
#    'rejected': False},
#   'kolmogorov_smirnov': {'test_statistic': 0.011717515199629047,
# ...

# %%
phi.get_test_chi_square("beta")
# Out:
# {'test_statistic': 27.57659041908268,
#  'critical_value': 21.02606981748307,
#  'p_value': 0.006377072851542209,
#  'rejected': True}
