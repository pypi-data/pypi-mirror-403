# %%
import sys
sys.path.append("../../../")
import phitter

# %%
def get_data(path: str) -> list[float | int]:
    sample_distribution_file = open(path, "r", encoding="utf-8-sig")
    data = [float(x.replace(",", ".")) for x in sample_distribution_file.read().splitlines()]
    sample_distribution_file.close()
    return data

# %%
path = "../../../datasets_test/discrete/sample_binomial.txt"
data = get_data(path)

# %%
phi = phitter.Phitter(data=data, fit_type="discrete")
phi.fit(n_workers=2)

# %%
phi.summarize()
# Out:
#      distribution           aic           bic           parameters chi_square  \
# 0        binomial   7684.883044   7696.235992     n: 10, p: 0.6994          ✅
# 1  hypergeometric   7711.438676   7728.468097  N: 50, K: 31, n: 11         ✖️
# 2         poisson   8820.368928   8826.045402        lambda: 6.942         ✖️
# 3         uniform   9937.352091   9948.705038          a: 1, b: 10         ✖️
# 4       geometric  12347.981399  12353.657872             p: 0.144         ✖️
# 5     logarithmic  14518.550470  14524.226944            p: 0.9559         ✖️
#
#   kolmogorov_smirnov
# 0                  ✅
# 1                 ✖️
# 2                 ✖️
# 3                 ✖️
# 4                 ✖️
# 5                 ✖️

# %%
phi.df_not_rejected_distributions
# Out:
#   distribution          aic          bic        parameters     chi_square  \
#                                                            test_statistic
# 0     binomial  7684.883044  7696.235992  n: 10, p: 0.6994      11.859797
#
#                                     kolmogorov_smirnov                 \
#   critical_value   p_value rejected     test_statistic critical_value
# 0       14.06714  0.105265    False           0.026195       0.029164
#
#
#     p_value rejected
# 0  0.101803    False

# %%
phi.df_sorted_distributions
# Out:
#      distribution passed           aic           bic           parameters  \
#
# 0        binomial      ✅   7684.883044   7696.235992     n: 10, p: 0.6994
# 1  hypergeometric     ✖️   7711.438676   7728.468097  N: 50, K: 31, n: 11
# 2         poisson     ✖️   8820.368928   8826.045402        lambda: 6.942
# 3         uniform     ✖️   9937.352091   9948.705038          a: 1, b: 10
# 4       geometric     ✖️  12347.981399  12353.657872             p: 0.144
# 5     logarithmic     ✖️  14518.550470  14524.226944            p: 0.9559
#
#       chi_square                                   kolmogorov_smirnov  \
#   test_statistic critical_value   p_value rejected     test_statistic
# 0      11.859797      14.067140  0.105265    False           0.026195
# 1      26.051783      12.591587  0.000218     True           0.046808
# 2     668.691462      15.507313  0.000000     True           0.149154
# 3    1980.421296      14.067140  0.000000     True           0.354103
# 4    4777.090630      15.507313  0.000000     True           0.417326
# 5    9885.641776      15.507313  0.000000     True           0.566948
#
#
#   critical_value   p_value rejected
# 0       0.029164  0.101803    False
# 1       0.029164  0.000152     True
# 2       0.029164  0.000000     True
# 3       0.029164  0.000000     True
# 4       0.029164  0.000000     True
# 5       0.029164  0.000000     True
