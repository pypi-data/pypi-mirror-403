# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/phitter-hub/phitter-kernel/blob/main/examples/fit_discrete.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import os
import pandas

# %%
if os.getenv("COLAB_RELEASE_TAG"):
   # !pip install phitter --quiet
else:
   sys.path.append("../../")

# %%
import phitter

# %%
df = pandas.read_csv("https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/datasets/warpbreaks.csv")
df.head()
# Out:
#    rownames  breaks wool tension
# 0         1      26    A       L
# 1         2      30    A       L
# 2         3      54    A       L
# 3         4      25    A       L
# 4         5      70    A       L

# %%
data = df["breaks"].to_numpy()

# %%
phi = phitter.Phitter(
    data=data,
    fit_type="discrete",
)
phi.fit()

# %%
phi.best_distribution
# Out:
# {'id': 'negative_binomial', 'parameters': {'r': 5, 'p': 0.1615814766974479}}

# %%
phi.df_sorted_distributions
# Out:
#         distribution passed          aic          bic              parameters  \
#
# 0  negative_binomial      ✅   423.895234   427.873202         r: 5, p: 0.1616
# 1          geometric      ✅   468.506458   470.495442              p: 0.03553
# 2        logarithmic      ✅   546.410694   548.399678               p: 0.9929
# 3            poisson      ✅   574.036289   576.025274           lambda: 28.15
# 4            uniform     ✖️   447.974377   451.952345            a: 10, b: 70
# 5     hypergeometric     ✖️  2629.888393  2635.855345  N: 647, K: 197, n: 193
#
#       chi_square                                   kolmogorov_smirnov  \
#   test_statistic critical_value   p_value rejected     test_statistic
# 0      49.500000      76.777803  0.778962    False           0.125908
# 1      70.000000      77.930524  0.154746    False           0.341794
# 2      77.500000      77.930524  0.053499    False           0.592349
# 3      65.000000      77.930524  0.275729    False           0.306256
# 4      77.000000      76.777803  0.048259     True           0.380085
# 5     114.833333      75.623748  0.000009     True           0.903948
#
#
#   critical_value       p_value rejected
# 0       0.181438  3.307471e-01    False
# 1       0.181438  3.903182e-06     True
# 2       0.181438  0.000000e+00     True
# 3       0.181438  5.410195e-05     True
# 4       0.181438  1.601154e-07     True
# 5       0.181438  0.000000e+00     True

# %%
phi.plot_histogram()

# %%
phi.plot_histogram_distributions()

# %%
phi.plot_distribution("poisson")

# %%
phi.plot_ecdf()

# %%
phi.plot_ecdf_distribution("poisson")

# %%
phi.qq_plot("poisson")

# %%
phi.qq_plot_regression("poisson")
