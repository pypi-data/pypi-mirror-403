# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/phitter-hub/phitter-kernel/blob/main/examples/fit_specific_distribution.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TUTORIAL: FIT SPECIFIC DISTRIBUTIONS**

# %%
import os
import sys

# %%
if os.getenv("COLAB_RELEASE_TAG"):
   # !pip install phitter --quiet
else:
   sys.path.append("../../")

# %%
import phitter

# %% [markdown]
# **Initializes distribution providing a dict with patameters specified in documentation**

# %%
distribution = phitter.continuous.Beta({"alpha": 5, "beta": 2, "A": 100, "B": 1000})
data = distribution.sample(10000)

# %% [markdown]
# **Initialize the PHITTER model**

# %%
phi = phitter.Phitter(data=data, distributions_to_fit=["beta"])
phi.fit()

# %% [markdown]
# **Summarize**

# %%
phi.summarize()
# Out:
#   distribution            aic           bic  \
# 0         beta  186291.857699  186320.69906
#
#                                       parameters chi_square  \
# 0  alpha: 4.383, beta: 1.735, A: 137.9, B: 984.6         ✖️
#
#   kolmogorov_smirnov anderson_darling
# 0                  ✅               ✖️

# %% [markdown]
# **Get distrbutions sorted by sse**

# %%
phi.df_sorted_distributions
# Out:
#   distribution passed            aic           bic  \
#
# 0         beta      ✅  186291.857699  186320.69906
#
#                                       parameters     chi_square  \
#                                                  test_statistic
# 0  alpha: 4.383, beta: 1.735, A: 137.9, B: 984.6      48.936093
#
#                                     kolmogorov_smirnov                 \
#   critical_value   p_value rejected     test_statistic critical_value
# 0       24.99579  0.000018     True           0.008867       0.013564
#
#                      anderson_darling
#     p_value rejected   test_statistic critical_value p_value rejected
# 0  0.409052    False             None           None    None     None

# %% [markdown]
# **Plot a histogram of the dataset values to visualize the distribution**

# %%
phi.plot_histogram_distributions()
