# %% [markdown]
# # Core Module
#
# Another module to show hooks being called for each notebook.

# %%
#|default_exp core

# %%
#|export
VERSION = "1.0.0"

# %%
#|export
def get_version() -> str:
    """Get the version."""
    return VERSION
