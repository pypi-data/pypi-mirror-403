# %%
#|default_exp this_wont_be_exported

# %%
#|export
"Any code in a notebook that begins with a dunder '__' or is in a folder starting with a dunder will not be exported."
# Out:
# "Any code in a notebook that begins with a dunder '__' or is in a folder starting with a dunder will not be exported."
