# %% [markdown]
# # `#|export_to` directive (example 2)
#
# Any cell exported using `#|export` will by default have order value `0` (e.g. `#|export 0`), which means they will by default appear above any cell exported using `#|export_to`.

# %%
#|default_exp export_to_demo

# %%
#|export
def this_will_first_of_all():
    """Explicitly specifies the target module."""
    return "explicit"
