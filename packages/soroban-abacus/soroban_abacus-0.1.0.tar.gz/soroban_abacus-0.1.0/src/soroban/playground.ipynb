# %%
from soroban import Soroban

# %%
s = Soroban(5)
s.from_decimal(17)
print(s)
# Out:
# 0: ○● | ●●○○
# 1: ●○ | ●○○○
# 2: ●○ | ○○○○
# 3: ●○ | ○○○○
# 4: ●○ | ○○○○

# %%
s.to_svg("soroban1.svg")

# %%
s = Soroban(12)
s.from_decimal(1234567890)

# %%
s.to_svg("soroban2.svg")
