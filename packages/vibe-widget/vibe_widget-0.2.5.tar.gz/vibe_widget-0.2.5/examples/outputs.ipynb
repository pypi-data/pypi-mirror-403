# %%
pip install "numpy<2" "gym==0.26.2" "gym-super-mario-bros==7.4.0" "nes-py==8.2.1"
# Out:
# Collecting numpy<2
#   Using cached numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (61 kB)
# Requirement already satisfied: gym==0.26.2 in /Users/dwootton/miniconda3/lib/python3.12/site-packages (0.26.2)
# Requirement already satisfied: gym-super-mario-bros==7.4.0 in /Users/dwootton/miniconda3/lib/python3.12/site-packages (7.4.0)
# Requirement already satisfied: nes-py==8.2.1 in /Users/dwootton/miniconda3/lib/python3.12/site-packages (8.2.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/dwootton/miniconda3/lib/python3.12/site-packages (from gym==0.26.2) (3.1.1)
# Requirement already satisfied: gym_notices>=0.0.4 in /Users/dwootton/miniconda3/lib/python3.12/site-packages (from gym==0.26.2) (0.1.0)
# Requirement already satisfied: pyglet<=1.5.21,>=1.4.0 in /Users/dwootton/miniconda3/lib/python3.12/site-packages (from nes-py==8.2.1) (1.5.21)
# Requirement already satisfied: tqdm>=4.48.2 in /Users/dwootton/miniconda3/lib/python3.12/site-packages (from nes-py==8.2.1) (4.66.5)
# Using cached numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl (13.7 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.5
#     Uninstalling numpy-2.2.5:
#       Successfully uninstalled numpy-2.2.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import vibe_widget as vw
import os
import dotenv
dotenv.load_dotenv()
vw.config(api_key=os.getenv("OPENROUTER_API_KEY"))
# Out:
# Config(model='google/gemini-3-flash-preview', api_key='****', temperature=0.7, streaming=True, mode='standard', theme=None, execution='auto')

# %%
  import gym
  import gym_super_mario_bros
  from nes_py.wrappers import JoypadSpace
  from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
  import vibe_widget as vw

  env = JoypadSpace(gym_super_mario_bros.make("SuperMarioBros-1-1-v0"), SIMPLE_MOVEMENT)

  reset_out = env.reset()
  if isinstance(reset_out, tuple):
      obs = reset_out[0]
      info = reset_out[1] if len(reset_out) > 1 else {}
  else:
      obs, info = reset_out, {}

  widget = vw.create(
      """Create a Mario viewer:
      - Show the current frame from 'frame'
      - Show score, coins, and time from 'info'
      - Provide action buttons labeled from 'action_names'
      - Output the selected action index as 'action'""",
     inputs=vw.inputs(
            frame=obs,
            info=info,
            action_names=[str(a) for a in SIMPLE_MOVEMENT],
      ),
      cache=False,
      outputs=vw.outputs(action="index of selected action"),
  )

  def step_env(event):
      step_out = env.step(event.new)
      if len(step_out) == 5:
          obs, reward, terminated, truncated, info = step_out
          done = terminated or truncated
      else:
          obs, reward, done, info = step_out

      with widget.inputs.batch():
          widget.inputs.frame = obs
          widget.inputs.info = info

      if done:
          reset_out = env.reset()
          if isinstance(reset_out, tuple):
              obs = reset_out[0]
              info = reset_out[1] if len(reset_out) > 1 else {}
          else:
              obs, info = reset_out, {}
          with widget.inputs.batch():
              widget.inputs.frame = obs
              widget.inputs.info = info

  widget.outputs.action.observe(step_env)
# Out:
# /Users/dwootton/miniconda3/lib/python3.12/site-packages/gym/envs/registration.py:555: UserWarning: WARN: The environment SuperMarioBros-1-1-v0 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# /Users/dwootton/miniconda3/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'numpy.ndarray'>`
#   logger.warn(
# DynamicVibeWidget(action=<VibeExport Create a Mario viewer:
#     - Show the current frame from 'frame'
#     - Sh...
# <function __main__.step_env(event)>

# %%
  print(widget.status)
  print(widget.error_message)
  print(widget.logs[-5:])
# Out:
# ready
#
# ['Testing runtime', '✓ Widget generation complete', 'Code generated: 4444 characters', 'Widget saved: create_mario_viewer_show_current_frame_f v3', 'Location: .vibewidget/widgets/create_mario_viewer_show_current_frame_f__d30e6f6257__v3.js']
