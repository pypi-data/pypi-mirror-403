# %%
from podcast_creator.graph import create_podcast

from content_core import extract_content

# use the content core library to extract content from a URL
# You can also use file_path for many types of files
# For example, to extract content from a PDF file, you can use:
# content = await extract_content(file_path="path/to/your/file.pdf")
content = await extract_content(dict(url="https://situational-awareness.ai/wp-content/uploads/2024/06/situationalawareness.pdf"))

briefing = """
Create an exciting podcast on the topic of situational awareness. 
"""

# Test with 2-speaker setup

result = await create_podcast(
    content=content,
    briefing=briefing,
    episode_name="diverse_panel",
    output_dir="output/diverse_panel",
    speaker_config="diverse_panel",
    outline_provider="openai",
    outline_model="gpt-4o-mini",
    transcript_provider="anthropic", 
    transcript_model="claude-3-5-sonnet-latest",
    num_segments=7
)
# Out:
# 2025-07-06 17:16:00.657 | DEBUG    | podcast_creator.config:get_template_prompter:231 - Using bundled template for 'outline'
# 2025-07-06 17:16:00.659 | DEBUG    | podcast_creator.config:get_template_prompter:231 - Using bundled template for 'transcript'
# 2025-07-06 17:16:01.439 | INFO     | podcast_creator.graph:<module>:18 - Creating podcast generation graph
# 2025-07-06 17:16:07.172 | INFO     | podcast_creator.nodes:generate_outline_node:22 - Starting outline generation
# 2025-07-06 17:16:20.962 | INFO     | podcast_creator.nodes:generate_outline_node:52 - Generated outline with 7 segments
# 2025-07-06 17:16:20.963 | INFO     | podcast_creator.nodes:generate_transcript_node:59 - Starting transcript generation
# 2025-07-06 17:16:21.292 | INFO     | podcast_creator.nodes:generate_transcript_node:87 - Generating transcript for segment 1/7: Welcome to the Future: An Introduction to Situational Awareness
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[1], line 14
#       8 briefing = """
#       9 Create an exciting podcast on the topic of situational awareness.
#      10 """
#      12 # Test with 2-speaker setup
# ---> 14 result = await create_podcast(
#      15     content=content,
#      16     briefing=briefing,
#      17     episode_name="diverse_panel",
#      18     output_dir="output/diverse_panel",
#      19     speaker_config="diverse_panel",
#      20     outline_provider="openai",
#      21     outline_model="gpt-4o-mini",
#      22     transcript_provider="anthropic",
#      23     transcript_model="claude-3-5-sonnet-latest",
#      24     num_segments=7
#      25 )
#
# File ~/dev/experimentos/podcast-creator/src/podcast_creator/graph.py:103, in create_podcast(content, briefing, episode_name, output_dir, speaker_config, outline_provider, outline_model, transcript_provider, transcript_model, num_segments)
#      93 config = {
#      94     "configurable": {
#      95         "outline_provider": outline_provider,
#    (...)     99     }
#     100 }
#     102 # Create and run the graph
# --> 103 result = await graph.ainvoke(initial_state, config=config)
#     105 # Save outputs
#     106 if result["outline"]:
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/langgraph/pregel/__init__.py:2919, in Pregel.ainvoke(self, input, config, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, **kwargs)
#    2916 chunks: list[dict[str, Any] | Any] = []
#    2917 interrupts: list[Interrupt] = []
# -> 2919 async for chunk in self.astream(
#    2920     input,
#    2921     config,
#    2922     stream_mode=["updates", "values"]
#    2923     if stream_mode == "values"
#    2924     else stream_mode,
#    2925     print_mode=print_mode,
#    2926     output_keys=output_keys,
#    2927     interrupt_before=interrupt_before,
#    2928     interrupt_after=interrupt_after,
#    2929     **kwargs,
#    2930 ):
#    2931     if stream_mode == "values":
#    2932         if len(chunk) == 2:
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/langgraph/pregel/__init__.py:2767, in Pregel.astream(self, input, config, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2765 for task in await loop.amatch_cached_writes():
#    2766     loop.output_writes(task.id, task.writes, cached=True)
# -> 2767 async for _ in runner.atick(
#    2768     [t for t in loop.tasks.values() if not t.writes],
#    2769     timeout=self.step_timeout,
#    2770     get_waiter=get_waiter,
#    2771     schedule_task=loop.aaccept_push,
#    2772 ):
#    2773     # emit output
#    2774     for o in _output(
#    2775         stream_mode,
#    2776         print_mode,
#    (...)   2779         asyncio.QueueEmpty,
#    2780     ):
#    2781         yield o
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/langgraph/pregel/runner.py:295, in PregelRunner.atick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     293 t = tasks[0]
#     294 try:
# --> 295     await arun_with_retry(
#     296         t,
#     297         retry_policy,
#     298         stream=self.use_astream,
#     299         configurable={
#     300             CONFIG_KEY_CALL: partial(
#     301                 _acall,
#     302                 weakref.ref(t),
#     303                 stream=self.use_astream,
#     304                 retry_policy=retry_policy,
#     305                 futures=weakref.ref(futures),
#     306                 schedule_task=schedule_task,
#     307                 submit=self.submit,
#     308                 loop=loop,
#     309             ),
#     310         },
#     311     )
#     312     self.commit(t, None)
#     313 except Exception as exc:
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/langgraph/pregel/retry.py:137, in arun_with_retry(task, retry_policy, stream, match_cached_writes, configurable)
#     135         break
#     136     else:
# --> 137         return await task.proc.ainvoke(task.input, config)
#     138 except ParentCommand as exc:
#     139     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/langgraph/utils/runnable.py:672, in RunnableSeq.ainvoke(self, input, config, **kwargs)
#     670     # run in context
#     671     with set_config_context(config, run) as context:
# --> 672         input = await asyncio.create_task(
#     673             step.ainvoke(input, config, **kwargs), context=context
#     674         )
#     675 else:
#     676     input = await step.ainvoke(input, config, **kwargs)
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/langgraph/utils/runnable.py:440, in RunnableCallable.ainvoke(self, input, config, **kwargs)
#     438         await run_manager.on_chain_end(ret)
#     439 else:
# --> 440     ret = await self.afunc(*args, **kwargs)
#     441 if self.recurse and isinstance(ret, Runnable):
#     442     return await ret.ainvoke(input, config)
#
# File ~/dev/experimentos/podcast-creator/src/podcast_creator/nodes.py:107, in generate_transcript_node(state, config)
#     105 transcript_prompt = get_transcript_prompter()
#     106 transcript_prompt_rendered = transcript_prompt.render(data)
# --> 107 transcript_preview = await transcript_model.ainvoke(transcript_prompt_rendered)
#     108 transcript_preview.content = clean_thinking_content(transcript_preview.content)
#     109 result = validated_transcript_parser.invoke(transcript_preview.content)
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:400, in BaseChatModel.ainvoke(self, input, config, stop, **kwargs)
#     390 @override
#     391 async def ainvoke(
#     392     self,
#    (...)    397     **kwargs: Any,
#     398 ) -> BaseMessage:
#     399     config = ensure_config(config)
# --> 400     llm_result = await self.agenerate_prompt(
#     401         [self._convert_input(input)],
#     402         stop=stop,
#     403         callbacks=config.get("callbacks"),
#     404         tags=config.get("tags"),
#     405         metadata=config.get("metadata"),
#     406         run_name=config.get("run_name"),
#     407         run_id=config.pop("run_id", None),
#     408         **kwargs,
#     409     )
#     410     return cast("ChatGeneration", llm_result.generations[0][0]).message
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:974, in BaseChatModel.agenerate_prompt(self, prompts, stop, callbacks, **kwargs)
#     965 @override
#     966 async def agenerate_prompt(
#     967     self,
#    (...)    971     **kwargs: Any,
#     972 ) -> LLMResult:
#     973     prompt_messages = [p.to_messages() for p in prompts]
# --> 974     return await self.agenerate(
#     975         prompt_messages, stop=stop, callbacks=callbacks, **kwargs
#     976     )
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:894, in BaseChatModel.agenerate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     881 run_managers = await callback_manager.on_chat_model_start(
#     882     self._serialized,
#     883     messages_to_trace,
#    (...)    888     run_id=run_id,
#     889 )
#     891 input_messages = [
#     892     _normalize_messages(message_list) for message_list in messages
#     893 ]
# --> 894 results = await asyncio.gather(
#     895     *[
#     896         self._agenerate_with_cache(
#     897             m,
#     898             stop=stop,
#     899             run_manager=run_managers[i] if run_managers else None,
#     900             **kwargs,
#     901         )
#     902         for i, m in enumerate(input_messages)
#     903     ],
#     904     return_exceptions=True,
#     905 )
#     906 exceptions = []
#     907 for i, res in enumerate(results):
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:1100, in BaseChatModel._agenerate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1098     result = generate_from_stream(iter(chunks))
#    1099 elif inspect.signature(self._agenerate).parameters.get("run_manager"):
# -> 1100     result = await self._agenerate(
#    1101         messages, stop=stop, run_manager=run_manager, **kwargs
#    1102     )
#    1103 else:
#    1104     result = await self._agenerate(messages, stop=stop, **kwargs)
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/langchain_anthropic/chat_models.py:1522, in ChatAnthropic._agenerate(self, messages, stop, run_manager, **kwargs)
#    1520 payload = self._get_request_payload(messages, stop=stop, **kwargs)
#    1521 try:
# -> 1522     data = await self._acreate(payload)
#    1523 except anthropic.BadRequestError as e:
#    1524     _handle_anthropic_bad_request(e)
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/langchain_anthropic/chat_models.py:1370, in ChatAnthropic._acreate(self, payload)
#    1368     return await self._async_client.beta.messages.create(**payload)
#    1369 else:
# -> 1370     return await self._async_client.messages.create(**payload)
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/anthropic/resources/messages/messages.py:2272, in AsyncMessages.create(self, max_tokens, messages, model, metadata, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#    2265 if model in DEPRECATED_MODELS:
#    2266     warnings.warn(
#    2267         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#    2268         DeprecationWarning,
#    2269         stacklevel=3,
#    2270     )
# -> 2272 return await self._post(
#    2273     "/v1/messages",
#    2274     body=await async_maybe_transform(
#    2275         {
#    2276             "max_tokens": max_tokens,
#    2277             "messages": messages,
#    2278             "model": model,
#    2279             "metadata": metadata,
#    2280             "service_tier": service_tier,
#    2281             "stop_sequences": stop_sequences,
#    2282             "stream": stream,
#    2283             "system": system,
#    2284             "temperature": temperature,
#    2285             "thinking": thinking,
#    2286             "tool_choice": tool_choice,
#    2287             "tools": tools,
#    2288             "top_k": top_k,
#    2289             "top_p": top_p,
#    2290         },
#    2291         message_create_params.MessageCreateParamsStreaming
#    2292         if stream
#    2293         else message_create_params.MessageCreateParamsNonStreaming,
#    2294     ),
#    2295     options=make_request_options(
#    2296         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    2297     ),
#    2298     cast_to=Message,
#    2299     stream=stream or False,
#    2300     stream_cls=AsyncStream[RawMessageStreamEvent],
#    2301 )
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/anthropic/_base_client.py:1888, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1874 async def post(
#    1875     self,
#    1876     path: str,
#    (...)   1883     stream_cls: type[_AsyncStreamT] | None = None,
#    1884 ) -> ResponseT | _AsyncStreamT:
#    1885     opts = FinalRequestOptions.construct(
#    1886         method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1887     )
# -> 1888     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/anthropic/_base_client.py:1623, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1621 response = None
#    1622 try:
# -> 1623     response = await self._client.send(
#    1624         request,
#    1625         stream=stream or self._should_stream_response_body(request=request),
#    1626         **kwargs,
#    1627     )
#    1628 except httpx.TimeoutException as err:
#    1629     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/httpx/_client.py:1629, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1625 self._set_timeout(request)
#    1627 auth = self._build_request_auth(request, auth)
# -> 1629 response = await self._send_handling_auth(
#    1630     request,
#    1631     auth=auth,
#    1632     follow_redirects=follow_redirects,
#    1633     history=[],
#    1634 )
#    1635 try:
#    1636     if not stream:
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/httpx/_client.py:1657, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1654 request = await auth_flow.__anext__()
#    1656 while True:
# -> 1657     response = await self._send_handling_redirects(
#    1658         request,
#    1659         follow_redirects=follow_redirects,
#    1660         history=history,
#    1661     )
#    1662     try:
#    1663         try:
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/httpx/_client.py:1694, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1691 for hook in self._event_hooks["request"]:
#    1692     await hook(request)
# -> 1694 response = await self._send_single_request(request)
#    1695 try:
#    1696     for hook in self._event_hooks["response"]:
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/httpx/_client.py:1730, in AsyncClient._send_single_request(self, request)
#    1725     raise RuntimeError(
#    1726         "Attempted to send an sync request with an AsyncClient instance."
#    1727     )
#    1729 with request_context(request=request):
# -> 1730     response = await transport.handle_async_request(request)
#    1732 assert isinstance(response.stream, AsyncByteStream)
#    1733 response.request = request
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/httpx/_transports/default.py:394, in AsyncHTTPTransport.handle_async_request(self, request)
#     381 req = httpcore.Request(
#     382     method=request.method,
#     383     url=httpcore.URL(
#    (...)    391     extensions=request.extensions,
#     392 )
#     393 with map_httpcore_exceptions():
# --> 394     resp = await self._pool.handle_async_request(req)
#     396 assert isinstance(resp.stream, typing.AsyncIterable)
#     398 return Response(
#     399     status_code=resp.status,
#     400     headers=resp.headers,
#     401     stream=AsyncResponseStream(resp.stream),
#     402     extensions=resp.extensions,
#     403 )
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/httpcore/_async/connection_pool.py:256, in AsyncConnectionPool.handle_async_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     await self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.AsyncIterable)
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/httpcore/_async/connection_pool.py:236, in AsyncConnectionPool.handle_async_request(self, request)
#     232 connection = await pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = await connection.handle_async_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/httpcore/_async/connection.py:103, in AsyncHTTPConnection.handle_async_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return await self._connection.handle_async_request(request)
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/httpcore/_async/http11.py:136, in AsyncHTTP11Connection.handle_async_request(self, request)
#     134     async with Trace("response_closed", logger, request) as trace:
#     135         await self._response_closed()
# --> 136 raise exc
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/httpcore/_async/http11.py:106, in AsyncHTTP11Connection.handle_async_request(self, request)
#      95     pass
#      97 async with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = await self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/httpcore/_async/http11.py:177, in AsyncHTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = await self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/httpcore/_async/http11.py:217, in AsyncHTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = await self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/httpcore/_backends/anyio.py:35, in AnyIOStream.read(self, max_bytes, timeout)
#      33 with anyio.fail_after(timeout):
#      34     try:
# ---> 35         return await self._stream.receive(max_bytes=max_bytes)
#      36     except anyio.EndOfStream:  # pragma: nocover
#      37         return b""
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/anyio/streams/tls.py:219, in TLSStream.receive(self, max_bytes)
#     218 async def receive(self, max_bytes: int = 65536) -> bytes:
# --> 219     data = await self._call_sslobject_method(self._ssl_object.read, max_bytes)
#     220     if not data:
#     221         raise EndOfStream
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/anyio/streams/tls.py:162, in TLSStream._call_sslobject_method(self, func, *args)
#     159     if self._write_bio.pending:
#     160         await self.transport_stream.send(self._write_bio.read())
# --> 162     data = await self.transport_stream.receive()
#     163 except EndOfStream:
#     164     self._read_bio.write_eof()
#
# File ~/dev/experimentos/podcast-creator/.venv/lib/python3.11/site-packages/anyio/_backends/_asyncio.py:1254, in SocketStream.receive(self, max_bytes)
#    1248 if (
#    1249     not self._protocol.read_event.is_set()
#    1250     and not self._transport.is_closing()
#    1251     and not self._protocol.is_at_eof
#    1252 ):
#    1253     self._transport.resume_reading()
# -> 1254     await self._protocol.read_event.wait()
#    1255     self._transport.pause_reading()
#    1256 else:
#
# File ~/.local/share/uv/python/cpython-3.11.7-macos-aarch64-none/lib/python3.11/asyncio/locks.py:213, in Event.wait(self)
#     211 self._waiters.append(fut)
#     212 try:
# --> 213     await fut
#     214     return True
#     215 finally:
#
# CancelledError:
