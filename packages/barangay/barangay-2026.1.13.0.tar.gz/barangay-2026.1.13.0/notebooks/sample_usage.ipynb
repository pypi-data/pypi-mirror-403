# %% [markdown]
# # Fuzzy Search

# %%
from barangay import search

search("Tongmageng, Tawi-Tawi")
# Out:
# [{'barangay': 'Tongmageng',
#   'province_or_huc': 'Tawi-Tawi',
#   'municipality_or_city': 'Sitangkai',
#   'psgc_id': '1907005010',
#   'f_0p0b_ratio_score': 100.0,
#   'f_00mb_ratio_score': 76.92307692307692,
#   'f_0pmb_ratio_score': 79.16666666666666,
#   '000b': 'tongmageng',
#   '0p0b': 'tawitawi tongmageng',
#   '00mb': 'sitangkai tongmageng',
#   '0pmb': 'tawitawi sitangkai tongmageng'},
#  {'barangay': 'Tonggosong',
#   'province_or_huc': 'Tawi-Tawi',
#   'municipality_or_city': 'Simunul',
#   'psgc_id': '1907004005',
#   'f_0p0b_ratio_score': 84.21052631578947,
#   'f_00mb_ratio_score': 48.64864864864865,
#   'f_0pmb_ratio_score': 69.56521739130434,
#   '000b': 'tonggosong',
#   '0p0b': 'tawitawi tonggosong',
#   '00mb': 'simunul tonggosong',
#   '0pmb': 'tawitawi simunul tonggosong'},
#  {'barangay': 'Tongbangkaw',
#   'province_or_huc': 'Tawi-Tawi',
#   'municipality_or_city': 'Tandubas',
#   'psgc_id': '1907007042',
#   'f_0p0b_ratio_score': 82.05128205128204,
#   'f_00mb_ratio_score': 56.41025641025641,
#   'f_0pmb_ratio_score': 66.66666666666667,
#   '000b': 'tongbangkaw',
#   '0p0b': 'tawitawi tongbangkaw',
#   '00mb': 'tandubas tongbangkaw',
#   '0pmb': 'tawitawi tandubas tongbangkaw'},
#  {'barangay': 'Tongusong',
#   'province_or_huc': 'Tawi-Tawi',
#   'municipality_or_city': 'Sitangkai',
#   'psgc_id': '1907005012',
#   'f_0p0b_ratio_score': 81.08108108108108,
#   'f_00mb_ratio_score': 57.89473684210527,
#   'f_0pmb_ratio_score': 63.829787234042556,
#   '000b': 'tongusong',
#   '0p0b': 'tawitawi tongusong',
#   '00mb': 'sitangkai tongusong',
#   '0pmb': 'tawitawi sitangkai tongusong'},
#  {'barangay': 'Tongehat',
#   'province_or_huc': 'Tawi-Tawi',
#   'municipality_or_city': 'Sibutu',
#   'psgc_id': '1907011014',
#   'f_0p0b_ratio_score': 77.77777777777779,
#   'f_00mb_ratio_score': 47.05882352941176,
#   'f_0pmb_ratio_score': 65.11627906976744,
#   '000b': 'tongehat',
#   '0p0b': 'tawitawi tongehat',
#   '00mb': 'sibutu tongehat',
#   '0pmb': 'tawitawi sibutu tongehat'}]

# %%
# %%timeit
# performance: best effort
search("Tongmageng, Tawi-Tawi")
# Out:
# 81.8 ms ± 9.63 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
from barangay import search

search(
  "Rosario",
  n = 10,
  match_hooks=["municipality","barangay"],
  threshold=50.0,
)
# Out:
# [{'barangay': 'Rosario',
#   'province_or_huc': 'City of Pasig',
#   'municipality_or_city': None,
#   'psgc_id': '1381200017',
#   'f_00mb_ratio_score': 73.6842105263158,
#   '000b': 'rosario',
#   '0p0b': 'pasig rosario',
#   '00mb': 'none rosario',
#   '0pmb': 'pasig none rosario'},
#  {'barangay': 'Rosario',
#   'province_or_huc': 'Negros Oriental',
#   'municipality_or_city': 'City of Bais',
#   'psgc_id': '1804604027',
#   'f_00mb_ratio_score': 73.6842105263158,
#   '000b': 'rosario',
#   '0p0b': 'negros oriental rosario',
#   '00mb': 'bais rosario',
#   '0pmb': 'negros oriental bais rosario'},
#  {'barangay': 'Vila',
#   'province_or_huc': 'La Union',
#   'municipality_or_city': 'Rosario',
#   'psgc_id': '0103313034',
#   'f_00mb_ratio_score': 73.6842105263158,
#   '000b': 'vila',
#   '0p0b': 'la union vila',
#   '00mb': 'rosario vila',
#   '0pmb': 'la union rosario vila'},
#  {'barangay': 'Nasi',
#   'province_or_huc': 'Batangas',
#   'municipality_or_city': 'Rosario',
#   'psgc_id': '0401021028',
#   'f_00mb_ratio_score': 73.6842105263158,
#   '000b': 'nasi',
#   '0p0b': 'batangas nasi',
#   '00mb': 'rosario nasi',
#   '0pmb': 'batangas rosario nasi'},
#  {'barangay': 'Natu',
#   'province_or_huc': 'Batangas',
#   'municipality_or_city': 'Rosario',
#   'psgc_id': '0401021027',
#   'f_00mb_ratio_score': 73.6842105263158,
#   '000b': 'natu',
#   '0p0b': 'batangas natu',
#   '00mb': 'rosario natu',
#   '0pmb': 'batangas rosario natu'},
#  {'barangay': 'Bani',
#   'province_or_huc': 'La Union',
#   'municipality_or_city': 'Rosario',
#   'psgc_id': '0103313006',
#   'f_00mb_ratio_score': 73.6842105263158,
#   '000b': 'bani',
#   '0p0b': 'la union bani',
#   '00mb': 'rosario bani',
#   '0pmb': 'la union rosario bani'},
#  {'barangay': 'Udiao',
#   'province_or_huc': 'La Union',
#   'municipality_or_city': 'Rosario',
#   'psgc_id': '0103313033',
#   'f_00mb_ratio_score': 70.0,
#   '000b': 'udiao',
#   '0p0b': 'la union udiao',
#   '00mb': 'rosario udiao',
#   '0pmb': 'la union rosario udiao'},
#  {'barangay': 'Rabon',
#   'province_or_huc': 'La Union',
#   'municipality_or_city': 'Rosario',
#   'psgc_id': '0103313026',
#   'f_00mb_ratio_score': 70.0,
#   '000b': 'rabon',
#   '0p0b': 'la union rabon',
#   '00mb': 'rosario rabon',
#   '0pmb': 'la union rosario rabon'},
#  {'barangay': 'Tulos',
#   'province_or_huc': 'Batangas',
#   'municipality_or_city': 'Rosario',
#   'psgc_id': '0401021048',
#   'f_00mb_ratio_score': 70.0,
#   '000b': 'tulos',
#   '0p0b': 'batangas tulos',
#   '00mb': 'rosario tulos',
#   '0pmb': 'batangas rosario tulos'},
#  {'barangay': 'Rosario',
#   'province_or_huc': 'Capiz',
#   'municipality_or_city': 'Pilar',
#   'psgc_id': '0601911014',
#   'f_00mb_ratio_score': 70.0,
#   '000b': 'rosario',
#   '0p0b': 'capiz rosario',
#   '00mb': 'pilar rosario',
#   '0pmb': 'capiz pilar rosario'}]

# %%
# %%timeit
# performance: tuned to municipality and barangay (less match hooks, the faster)
search(
  "Rosario",
  n = 5,
  match_hooks=["municipality","barangay"],
  threshold=50.0,
)
# Out:
# 24.3 ms ± 737 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# # Accessing Barangay Data

# %%
from barangay import BARANGAY

# Example lookup process and dictionary traversal
all_regions = BARANGAY.keys()

ncr_cities_and_municipalities = list(BARANGAY["National Capital Region (NCR)"].keys())
print(f"NCR Cities & Municipalities: {ncr_cities_and_municipalities}")

municipalities_of_manila = list(
    BARANGAY["National Capital Region (NCR)"]["City of Manila"].keys()
)
print(f"Municipalities of Manila: {municipalities_of_manila}")

brgy_of_binondo = BARANGAY["National Capital Region (NCR)"]["City of Manila"]["Binondo"]
print(f"Brgys of Binondo: {brgy_of_binondo}")
# Out:
# NCR Cities & Municipalities: ['City of Manila', 'City of Caloocan', 'City of Las Piñas', 'City of Makati', 'City of Malabon', 'City of Mandaluyong', 'City of Marikina', 'City of Muntinlupa', 'City of Navotas', 'City of Parañaque', 'City of Pasig', 'City of San Juan', 'City of Taguig', 'City of Valenzuela', 'Pasay City', 'Quezon City', 'Pateros']
# Municipalities of Manila: ['Binondo', 'Ermita', 'Intramuros', 'Malate', 'Paco', 'Pandacan', 'Port Area', 'Quiapo', 'Sampaloc', 'San Miguel', 'San Nicolas', 'Santa Ana', 'Santa Cruz', 'Tondo I/II']
# Brgys of Binondo: ['Barangay 294', 'Barangay 295', 'Barangay 292', 'Barangay 288', 'Barangay 289', 'Barangay 287', 'Barangay 290', 'Barangay 291', 'Barangay 293', 'Barangay 296']

# %%
from barangay import BARANGAY_EXTENDED
from pprint import pprint

# Listing all component locations under Philippines
philippine_components = [item["name"] for item in BARANGAY_EXTENDED["components"]]
print("philippine_components: ")
pprint(philippine_components)
print("\n\n")

# retrieving National Capital Region (NCR) location data
ncr = [
    item
    for item in BARANGAY_EXTENDED["components"]
    if item["name"] == "National Capital Region (NCR)"
][0]

# Listing all component locations under NCR. In the output, notice tha Pateros is a
# municipality directly under a region, which is unusual but possible, nonetheless.
ncr_components = [(item["name"], item["type"]) for item in ncr["components"]]
print("ncr_components")
pprint(ncr_components)
print("\n\n")

# Retrieving City of Manila location data
city_of_manila = [
    item for item in ncr["components"] if item["name"] == "City of Manila"
][0]

# Listing all component locations under City of Manila
city_of_manila_components = [
    (item["name"], item["type"]) for item in city_of_manila["components"]
]
print("city_of_manila_components")
pprint(city_of_manila_components)
print("\n\n")

# Retrieving Sta Ana location data
sta_ana = [
    item for item in city_of_manila["components"] if item["name"] == "Santa Ana"
][0]

# Listing all component locations under Santa Ana (which are now the Barangay)
santa_ana_components = [
    (item["name"], item["type"]) for item in sta_ana["components"]
]
print("santa_ana_components")
pprint(santa_ana_components)
print("\n\n")
# Out:
# philippine_components:
# ['Bangsamoro Autonomous Region In Muslim Mindanao (BARMM)',
#  'Cordillera Administrative Region (CAR)',
#  'MIMAROPA Region',
#  'National Capital Region (NCR)',
#  'Negros Island Region (NIR)',
#  'Region I (Ilocos Region)',
#  'Region II (Cagayan Valley)',
#  'Region III (Central Luzon)',
#  'Region IV-A (CALABARZON)',
#  'Region IX (Zamboanga Peninsula)',
#  'Region V (Bicol Region)',
#  'Region VI (Western Visayas)',
#  'Region VII (Central Visayas)',
#  'Region VIII (Eastern Visayas)',
#  'Region X (Northern Mindanao)',
#  'Region XI (Davao Region)',
#  'Region XII (SOCCSKSARGEN)',
#  'Region XIII (Caraga)']
#
#
#
# ncr_components
# [('City of Caloocan', 'city'),
#  ('City of Las Piñas', 'city'),
#  ('City of Makati', 'city'),
#  ('City of Malabon', 'city'),
#  ('City of Mandaluyong', 'city'),
#  ('City of Manila', 'city'),
#  ('City of Marikina', 'city'),
#  ('City of Muntinlupa', 'city'),
#  ('City of Navotas', 'city'),
#  ('City of Parañaque', 'city'),
#  ('Pasay City', 'city'),
#  ('City of Pasig', 'city'),
#  ('Quezon City', 'city'),
#  ('City of San Juan', 'city'),
#  ('City of Taguig', 'city'),
#  ('City of Valenzuela', 'city'),
#  ('Pateros', 'municipality')]
#
#
#
# city_of_manila_components
# [('Tondo I/II', 'submunicipality'),
#  ('Binondo', 'submunicipality'),
#  ('Quiapo', 'submunicipality'),
#  ('San Nicolas', 'submunicipality'),
#  ('Santa Cruz', 'submunicipality'),
#  ('Sampaloc', 'submunicipality'),
#  ('San Miguel', 'submunicipality'),
#  ('Ermita', 'submunicipality'),
#  ('Intramuros', 'submunicipality'),
#  ('Malate', 'submunicipality'),
#  ('Paco', 'submunicipality'),
#  ('Pandacan', 'submunicipality'),
#  ('Port Area', 'submunicipality'),
#  ('Santa Ana', 'submunicipality')]
#
#
#
# santa_ana_components
# [('Barangay 745', 'barangay'),
#  ('Barangay 746', 'barangay'),
#  ('Barangay 747', 'barangay'),
#  ('Barangay 748', 'barangay'),
#  ('Barangay 749', 'barangay'),
#  ('Barangay 750', 'barangay'),
#  ('Barangay 751', 'barangay'),
#  ('Barangay 752', 'barangay'),
#  ('Barangay 753', 'barangay'),
#  ('Barangay 755', 'barangay'),
#  ('Barangay 756', 'barangay'),
#  ('Barangay 757', 'barangay'),
#  ('Barangay 758', 'barangay'),
#  ('Barangay 759', 'barangay'),
#  ('Barangay 760', 'barangay'),
#  ('Barangay 761', 'barangay'),
#  ('Barangay 762', 'barangay'),
#  ('Barangay 763', 'barangay'),
#  ('Barangay 764', 'barangay'),
#  ('Barangay 765', 'barangay'),
#  ('Barangay 766', 'barangay'),
#  ('Barangay 767', 'barangay'),
#  ('Barangay 768', 'barangay'),
#  ('Barangay 769', 'barangay'),
#  ('Barangay 770', 'barangay'),
#  ('Barangay 771', 'barangay'),
#  ('Barangay 772', 'barangay'),
#  ('Barangay 773', 'barangay'),
#  ('Barangay 774', 'barangay'),
#  ('Barangay 775', 'barangay'),
#  ('Barangay 776', 'barangay'),
#  ('Barangay 777', 'barangay'),
#  ('Barangay 778', 'barangay'),
#  ('Barangay 779', 'barangay'),
#  ('Barangay 780', 'barangay'),
#  ('Barangay 781', 'barangay'),
#  ('Barangay 782', 'barangay'),
#  ('Barangay 783', 'barangay'),
#  ('Barangay 784', 'barangay'),
#  ('Barangay 785', 'barangay'),
#  ('Barangay 786', 'barangay'),
#  ('Barangay 787', 'barangay'),
#  ('Barangay 788', 'barangay'),
#  ('Barangay 789', 'barangay'),
#  ('Barangay 790', 'barangay'),
#  ('Barangay 791', 'barangay'),
#  ('Barangay 792', 'barangay'),
#  ('Barangay 793', 'barangay'),
#  ('Barangay 794', 'barangay'),
#  ('Barangay 795', 'barangay'),
#  ('Barangay 796', 'barangay'),
#  ('Barangay 797', 'barangay'),
#  ('Barangay 798', 'barangay'),
#  ('Barangay 799', 'barangay'),
#  ('Barangay 800', 'barangay'),
#  ('Barangay 801', 'barangay'),
#  ('Barangay 802', 'barangay'),
#  ('Barangay 803', 'barangay'),
#  ('Barangay 804', 'barangay'),
#  ('Barangay 805', 'barangay'),
#  ('Barangay 806', 'barangay'),
#  ('Barangay 807', 'barangay'),
#  ('Barangay 866', 'barangay'),
#  ('Barangay 873', 'barangay'),
#  ('Barangay 874', 'barangay'),
#  ('Barangay 875', 'barangay'),
#  ('Barangay 876', 'barangay'),
#  ('Barangay 877', 'barangay'),
#  ('Barangay 878', 'barangay'),
#  ('Barangay 879', 'barangay'),
#  ('Barangay 880', 'barangay'),
#  ('Barangay 881', 'barangay'),
#  ('Barangay 882', 'barangay'),
#  ('Barangay 883', 'barangay'),
#  ('Barangay 884', 'barangay'),
#  ('Barangay 885', 'barangay'),
#  ('Barangay 886', 'barangay'),
#  ('Barangay 887', 'barangay'),
#  ('Barangay 888', 'barangay'),
#  ('Barangay 889', 'barangay'),
#  ('Barangay 890', 'barangay'),
#  ('Barangay 891', 'barangay'),
#  ('Barangay 892', 'barangay'),
#  ('Barangay 893', 'barangay'),
#  ('Barangay 894', 'barangay'),
#  ('Barangay 895', 'barangay'),
#  ('Barangay 896', 'barangay'),
#  ('Barangay 897', 'barangay'),
#  ('Barangay 898', 'barangay'),
#  ('Barangay 899', 'barangay'),
#  ('Barangay 900', 'barangay'),
#  ('Barangay 901', 'barangay'),
#  ('Barangay 902', 'barangay'),
#  ('Barangay 903', 'barangay'),
#  ('Barangay 904', 'barangay'),
#  ('Barangay 905', 'barangay'),
#  ('Barangay 754', 'barangay'),
#  ('Barangay 808', 'barangay'),
#  ('Barangay 818-A', 'barangay')]

# %%
from barangay import BARANGAY_FLAT


# Looking for Brgy. Marayos in Mindoro
brgy_marayos = [loc for loc in BARANGAY_FLAT if loc["name"]=="Marayos"]
print(brgy_marayos)

# From here we can now trace its hierarchy by following parent_psgc_id
brgy_marayos_parent = [loc for loc in BARANGAY_FLAT if loc["psgc_id"]=="1705209000"]
print(brgy_marayos_parent)

pinamalayan_parent = [loc for loc in BARANGAY_FLAT if loc["psgc_id"]=="1705200000"]
print(pinamalayan_parent)

oriental_mindoro_parent = [loc for loc in BARANGAY_FLAT if loc["psgc_id"]=="1700000000"]
print(oriental_mindoro_parent)
# Out:
# [{'name': 'Marayos', 'type': 'barangay', 'psgc_id': '1705209014', 'parent_psgc_id': '1705209000', 'nicknames': None}]
# [{'name': 'Pinamalayan', 'type': 'municipality', 'psgc_id': '1705209000', 'parent_psgc_id': '1705200000', 'nicknames': None}]
# [{'name': 'Oriental Mindoro', 'type': 'province', 'psgc_id': '1705200000', 'parent_psgc_id': '1700000000', 'nicknames': None}]
# [{'name': 'MIMAROPA Region', 'type': 'region', 'psgc_id': '1700000000', 'parent_psgc_id': '0000000000', 'nicknames': None}]
