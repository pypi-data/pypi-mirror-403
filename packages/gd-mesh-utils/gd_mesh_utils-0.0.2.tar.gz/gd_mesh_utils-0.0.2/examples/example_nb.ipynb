# %% [markdown]
# # Notebook Example

# %%
import pyvista as pv
import gdutils as gd
import gdmesh as gm

pv.set_jupyter_backend('static')

# %%
surface = pv.Cube().triangulate()
mesh = gm.Mesh.triangle_faces_from_pv(surface)

# %%
with gm.Plotter() as p:
    p.add_mesh(mesh)
# Out:
# Widget(value='<iframe src="http://localhost:41317/index.html?ui=P_0x740e04fbf650_0&reconnect=auto" class="pyvi…
