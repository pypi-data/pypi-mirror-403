# %%
from origami import OrigamiPipeline

pipeline = OrigamiPipeline.load("origami_mtg_model.pt")

# %%
data = pipeline.generate(1000)
# Out:
# ---------------------------------------------------------------------------
# GenerationError                           Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = pipeline.generate(1000)
#
# File ~/code/origami-v2/origami/pipeline/pipeline.py:704, in OrigamiPipeline.generate(self, num_samples, batch_size, max_length, temperature, top_k, top_p, seed, allow_complex_values)
#     701 generator = self._get_generator()
#     703 # Generate samples
# --> 704 samples = generator.generate(
#     705     num_samples=num_samples,
#     706     batch_size=batch_size,
#     707     max_length=max_length,
#     708     temperature=temperature,
#     709     top_k=top_k,
#     710     top_p=top_p,
#     711     seed=seed,
#     712     allow_complex_values=allow_complex_values,
#     713 )
#     715 # Inverse transform numeric fields if needed
#     716 if self._preprocessor is not None and self.config.data.numeric_mode == "scale":
#
# ...
