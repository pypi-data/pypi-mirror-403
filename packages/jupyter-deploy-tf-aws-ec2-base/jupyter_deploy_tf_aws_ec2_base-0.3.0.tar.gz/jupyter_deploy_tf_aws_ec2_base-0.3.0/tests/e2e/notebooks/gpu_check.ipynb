# %%
# !nvidia-smi

# %%
# Install PyTorch via pixi
# !pixi add --pypi torch

# %%
import torch

# %%
if not torch.cuda.is_available():
    raise RuntimeError("GPU not available")
print(f"GPU available: {torch.cuda.get_device_name(0)}")
