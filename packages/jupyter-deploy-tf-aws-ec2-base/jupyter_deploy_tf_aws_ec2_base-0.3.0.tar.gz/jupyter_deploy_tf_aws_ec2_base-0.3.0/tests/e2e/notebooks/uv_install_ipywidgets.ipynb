# %% [markdown]
# # UV Package Manager Test - Install ipywidgets
#
# Test installing a library via UV package manager.

# %%
# Install ipywidgets via uv
# !uv add ipywidgets

# %%
import ipywidgets

# %%
# Verify ipywidgets is functional
version = ipywidgets.__version__
print(f"ipywidgets version: {version}")

# %%
# Verify version exists
assert version, "ipywidgets version should not be empty"
print("✓ ipywidgets installed and functional")
