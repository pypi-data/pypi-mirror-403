# %% [markdown]
# # Simple Kernel Test
#
# Basic test to verify the Python kernel works.

# %%
# Basic arithmetic
result = 10 + 20 * 3
print(f"Kernel is working: {result}")

# %%
# Verify result
assert result == 70, f"Expected 70, got {result}"
print("✓ Kernel test passed")
