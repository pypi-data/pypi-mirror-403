# %% [markdown]
# # Import librairies

# %%
import pandas as pd
from sqlalchemy import text

from database_connection import create_postgres_engine
from modeling_database import build_incident_dataframes
from hazard_index import hazard_index_v16, HazardParams

# %% [markdown]
# # Connect to database

# %%
engine = create_postgres_engine("../../variables.env")

with engine.connect() as conn:
     print(conn.execute(text("SELECT version();")).scalar())
# Out:
# PostgreSQL 18.1 on aarch64-unknown-linux-gnu, compiled by aarch64-unknown-linux-gnu-gcc (GCC) 12.4.0, 64-bit

# %%
sql = text("""
SELECT *
FROM all_incidents ai
""")

with engine.connect() as conn:
    df = pd.read_sql(sql, conn)

df = df.sort_values("situation_record_creation_time", ascending=True)

# %% [markdown]
# # Building dataframe

# %%
df2 = build_incident_dataframes(df)

df2.to_csv("incidents_summary.csv", index=False)

df2.head()
# Out:
#    id                                run_id                     extracted_at  \
# 0   1  09690d63-6fc9-4d65-939d-a3352c1a70cf 2026-01-22 18:08:59.630945+00:00
# 1   2  09690d63-6fc9-4d65-939d-a3352c1a70cf 2026-01-22 18:08:59.630945+00:00
# 2   3  09690d63-6fc9-4d65-939d-a3352c1a70cf 2026-01-22 18:08:59.630945+00:00
# 3   4  09690d63-6fc9-4d65-939d-a3352c1a70cf 2026-01-22 18:08:59.630945+00:00
# 4   5  09690d63-6fc9-4d65-939d-a3352c1a70cf 2026-01-22 18:08:59.630945+00:00
#
#    situation_id situation_version  situation_record_id  \
# 0          6129              None                 9454
# 1         73792              None               120870
# 2         73813              None               120891
# 3        191105              None               324404
# 4        209887              None               355484
#
#    situation_record_version                     situation_type  \
# 0                         1  RoadOrCarriagewayOrLaneManagement
# 1                         1  RoadOrCarriagewayOrLaneManagement
# 2                         1  RoadOrCarriagewayOrLaneManagement
# 3                         1  RoadOrCarriagewayOrLaneManagement
# 4                         1  RoadOrCarriagewayOrLaneManagement
#
#   overall_severity severity  ... to_longitude to_kilometer_point  \
# 0              low      low  ...    -3.108543               19.0
# 1           medium   medium  ...    -5.761705                7.0
# 2          highest  highest  ...    -6.339432              464.2
# 3             high     high  ...    -5.534313               19.8
# 4             high     high  ...          NaN                NaN
#
#          to_municipality to_province  to_autonomous_community  \
# 0                 Murtas     Granada                Andalucía
# 1                  Gijón    Asturias  Asturias, Principado de
# 2                  Salas    Asturias  Asturias, Principado de
# 3  Quintana de la Serena     Badajoz              Extremadura
# 4                   None        None                     None
#
#   compliance_option vehicle_type management_type general_public_comment  \
# 0         mandatory   anyVehicle    laneClosures                   None
# 1         mandatory   anyVehicle    laneClosures                   None
# 2         mandatory   anyVehicle      roadClosed                   None
# 3         mandatory   anyVehicle      roadClosed                   None
# 4         mandatory   anyVehicle      roadClosed                   None
#
#   situation_record_end_time
# 0                       NaT
# 1                       NaT
# 2                       NaT
# 3                       NaT
# 4                       NaT
#
# [5 rows x 43 columns]

# %% [markdown]
# # Cleaning dataframe

# %%
cols_to_drop = [
    "situation_version", 
    "situation_record_version", 
    "overall_severity", 
    "probability_of_occurrence", 
    "information_status", 
    "source_identification", 
    "compliance_option", 
    "general_public_comment", 
    "situation_record_id", 
    "situation_record_version_time", 
    "id", 
    "run_id", 
    "extracted_at", 
    "situation_record_id", 
    "situation_record_version_time",
    "tpeg_location_type"
]

incidents_table = df2.drop(columns=cols_to_drop, errors="ignore")

# %%
df2.head()
# Out:
#    situation_id                     situation_type severity validity_status  \
# 0          6129  RoadOrCarriagewayOrLaneManagement      low          active
# 1         73792  RoadOrCarriagewayOrLaneManagement   medium          active
# 2         73813  RoadOrCarriagewayOrLaneManagement  highest          active
# 3        191105  RoadOrCarriagewayOrLaneManagement     high          active
# 4        209887  RoadOrCarriagewayOrLaneManagement     high          active
#
#   situation_record_creation_time validity_overall_start_time  \
# 0      2021-12-10 13:15:55+00:00   2021-09-07 13:00:00+00:00
# 1      2022-03-21 12:05:19+00:00   2021-02-24 11:40:00+00:00
# 2      2022-03-21 12:05:21+00:00   2021-08-03 15:09:00+00:00
# 3      2022-05-05 15:03:32+00:00   2018-12-18 11:05:00+00:00
# 4      2022-05-10 10:42:37+00:00   2022-05-10 10:35:00+00:00
#
#   validity_overall_end_time       cause_type detailed_cause_type  \
# 0                       NaT  roadMaintenance     roadMaintenance
# 1                       NaT  roadMaintenance     roadMaintenance
# 2                       NaT  roadMaintenance     roadMaintenance
# 3                       NaT  roadMaintenance     roadMaintenance
# 4                       NaT  roadMaintenance     roadMaintenance
#
#   cause_subtype  ... from_autonomous_community to_latitude to_longitude  \
# 0     roadworks  ...                 Andalucía   36.909466    -3.108543
# 1     roadworks  ...   Asturias, Principado de   43.555912    -5.761705
# 2     roadworks  ...   Asturias, Principado de   43.392933    -6.339432
# 3     roadworks  ...               Extremadura   38.983944    -5.534313
# 4     roadworks  ...                      None         NaN          NaN
#
#   to_kilometer_point        to_municipality  to_province  \
# 0               19.0                 Murtas      Granada
# 1                7.0                  Gijón     Asturias
# 2              464.2                  Salas     Asturias
# 3               19.8  Quintana de la Serena      Badajoz
# 4                NaN                   None         None
#
#    to_autonomous_community vehicle_type management_type  \
# 0                Andalucía   anyVehicle    laneClosures
# 1  Asturias, Principado de   anyVehicle    laneClosures
# 2  Asturias, Principado de   anyVehicle      roadClosed
# 3              Extremadura   anyVehicle      roadClosed
# 4                     None   anyVehicle      roadClosed
#
#   situation_record_end_time
# 0                       NaT
# 1                       NaT
# 2                       NaT
# 3                       NaT
# 4                       NaT
#
# [5 rows x 29 columns]

# %%
counts = incidents_table["situation_type"].value_counts(dropna=False)

print(counts)
# Out:
# situation_type
# GenericSituationRecord                    42031
# RoadOrCarriagewayOrLaneManagement          2257
# AbnormalTraffic                             957
# GeneralInstructionOrMessageToRoadUsers      199
# SpeedManagement                             162
# PoorEnvironmentConditions                   162
# MaintenanceWorks                            133
# NonWeatherRelatedRoadConditions              99
# GeneralObstruction                           83
# WinterDrivingManagement                      49
# VehicleObstruction                           17
# Name: count, dtype: int64

# %%
counts = incidents_table["severity"].value_counts(dropna=False)

print(counts)
# Out:
# severity
# None       44217
# medium      1204
# high         338
# low          242
# highest      148
# Name: count, dtype: int64

# %%
counts = incidents_table["validity_status"].value_counts(dropna=False)

print(counts)
# Out:
# validity_status
# inactive    45214
# active        935
# Name: count, dtype: int64

# %%
counts = incidents_table["cause_type"].value_counts(dropna=False)

print(counts)
# Out:
# cause_type
# vehicleObstruction                   40075
# obstruction                           2188
# poorEnvironment                        979
# roadMaintenance                        912
# abnormalTraffic                        896
# accident                               861
# environmentalObstruction               122
# roadOrCarriagewayOrLaneManagement       91
# infrastructureDamageObstruction         19
# disturbance                              4
# publicEvent                              2
# Name: count, dtype: int64

# %%
counts = incidents_table["detailed_cause_type"].value_counts(dropna=False)

print(counts)
# Out:
# detailed_cause_type
# None               44228
# roadMaintenance     1060
# accident             861
# Name: count, dtype: int64

# %%
counts = incidents_table["cause_subtype"].value_counts(dropna=False)
params = HazardParams(R0=1500, r=300, L=3, gamma=1.2, alpha=1.0, d0=500)
print(counts)
# Out:
# cause_subtype
# None                44228
# roadworks             912
# accident              861
# snowploughsInUse      148
# Name: count, dtype: int64

# %%
counts = incidents_table["carriageway"].value_counts(dropna=False)

print(counts)
# Out:
# carriageway
# None                      42059
# unspecifiedCarriageway     3755
# exitSlipRoad                218
# entrySlipRoad                59
# serviceRoad                  58
# Name: count, dtype: int64

# %%
counts = incidents_table["vehicle_type"].value_counts(dropna=False)

print(counts)
# Out:
# vehicle_type
# None                 43422
# anyVehicle            2186
# heavyVehicle           471
# bus                     46
# _extended               20
# car                      2
# largeGoodsVehicle        2
# Name: count, dtype: int64

# %%
counts = incidents_table["management_type"].value_counts(dropna=False)

print(counts)
# Out:
# management_type
# None                                        43667
# laneClosures                                 1239
# doNotUseSpecifiedLanesOrCarriageways          429
# narrowLanes                                   332
# roadClosed                                    145
# carriagewayClosures                            84
# other                                          80
# singleAlternateLineTraffic                     71
# vehicleStorageInOperation                      28
# newRoadworksLayout                             20
# lanesDeviated                                  16
# intermittentShortTermClosures                  13
# useOfSpecifiedLanesOrCarriagewaysAllowed       12
# _extended                                      11
# weightRestrictionInOperation                    2
# Name: count, dtype: int64

# %% [markdown]
# # Hazard index

# %%
df2 = pd.read_csv("../../data/incidents_summary.csv")

# %%
params = HazardParams(R0=1500, r=300, L=3, gamma=1.2, alpha=1.0, d0=500)

# %%
H, details = hazard_index_v16(
    params=params,
    q_lat=40.348436,
    q_lon=-3.861383,
    df2=df2,
    window_start="2026-01-25T00:00:00Z",
    return_details=True,
)

# %%
print("Hazard Index:", H)
print("Details:", details)
# Out:
# Hazard Index: 5.012486548264671
# Details: {'H': 5.012486548264671, 'window_start': Timestamp('2026-01-25 00:00:00+0000', tz='UTC'), 'window_end': Timestamp('2026-01-29 15:50:35.641951+0000', tz='UTC'), 'N_active_anytime': 25976, 'seed_count': 34, 'visited_count': 34, 'beta': [1.0, 0.5459180944327432, 0.4313440936655467, 0.3754383383374634], 'layer_weight_sums': [5.012486548264671, 0.0, 0.0, 0.0], 'layers_index': [[19782, 20709, 2155, 12100, 5612, 12707, 7770, 14366, 15808, 11849, 1592, 782, 10403, 17320, 23032, 20291, 366, 25572, 23830, 13418, 23758, 1493, 7284, 2541, 19311, 7731, 13479, 13269, 19165, 14666, 14274, 13134, 5478, 11443], [], [], []], 'layers_situation_id': [[16209633, 16211936, 16150964, 16182487, 16161506, 16184006, 16169213, 16189888, 16195502, 16181911, 16149329, 16146450, 16178166, 16200860, 16221091, 16210897, 16144966, 16231451, 16224152, 16186330, 16223829, 16148978, 16167666, 16152045, 16208257, 16169109, 16186521, 16185725, 16207822, 16190913, 16189538, 16185212, 16160966, 16180995], [], [], []]}

# %%
40.473089, -3.764716
