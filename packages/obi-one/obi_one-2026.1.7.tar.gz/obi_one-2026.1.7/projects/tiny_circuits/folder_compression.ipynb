# %%
import obi_one as obi
from pathlib import Path

# %%
# Volumetric
# input_root = Path("../../../obi-output/decontainerized_small_microcircuits_volumetric")
# output_root = Path("../../../obi-output/compressed_small_microcircuits_volumetrics")

# Hippocampus
# input_root = Path("../../../obi-output/extracted_small_microcircuits_hippocampus/")
# output_root = Path("../../../obi-output/compressed_small_microcircuits_hippocampus")

# Simplex
# input_root = Path("../../../obi-output/decontainerized_small_microcircuits_simplex")
# output_root = Path("../../../obi-output/compressed_small_microcircuits_simplex")

# Pairs
input_root = Path("../../../obi-output/decontainerized_small_microcircuits_motif")
output_root = Path("../../../obi-output/compressed_small_microcircuits_motif")

# %%
folder_compressions_scan_config = obi.FolderCompressionScanConfig(
                    initialize=obi.FolderCompressionScanConfig.Initialize(
                        folder_path=[
                            # Volumetric
                            # obi.NamedPath(name="nbS1-O1-vSub-nCN-HEX0-L1-01", path=str(input_root / "nbS1-O1-vSub-nCN-HEX0-L1-01")),
                            # obi.NamedPath(name="nbS1-O1-vSub-nCN-HEX0-L2-01", path=str(input_root / "nbS1-O1-vSub-nCN-HEX0-L2-01")),
                            # obi.NamedPath(name="nbS1-O1-vSub-nCN-HEX0-L3-01", path=str(input_root / "nbS1-O1-vSub-nCN-HEX0-L3-01")),
                            # obi.NamedPath(name="nbS1-O1-vSub-nCN-HEX0-L4-01", path=str(input_root / "nbS1-O1-vSub-nCN-HEX0-L4-01")),
                            # obi.NamedPath(name="nbS1-O1-vSub-nCN-HEX0-L5-01", path=str(input_root / "nbS1-O1-vSub-nCN-HEX0-L5-01")),
                            # obi.NamedPath(name="nbS1-O1-vSub-nCN-HEX0-L6-01", path=str(input_root / "nbS1-O1-vSub-nCN-HEX0-L6-01")),
                            
                            # obi.NamedPath(name="nbS1-O1-vSub-sCN-HEX0-L1-01", path=str(input_root / "nbS1-O1-vSub-sCN-HEX0-L1-01")),
                            # obi.NamedPath(name="nbS1-O1-vSub-sCN-HEX0-L2-01", path=str(input_root / "nbS1-O1-vSub-sCN-HEX0-L2-01")),
                            # obi.NamedPath(name="nbS1-O1-vSub-sCN-HEX0-L3-01", path=str(input_root / "nbS1-O1-vSub-sCN-HEX0-L3-01")),
                            # obi.NamedPath(name="nbS1-O1-vSub-sCN-HEX0-L4-01", path=str(input_root / "nbS1-O1-vSub-sCN-HEX0-L4-01")),
                            # obi.NamedPath(name="nbS1-O1-vSub-sCN-HEX0-L5-01", path=str(input_root / "nbS1-O1-vSub-sCN-HEX0-L5-01")),
                            # obi.NamedPath(name="nbS1-O1-vSub-sCN-HEX0-L6-01", path=str(input_root / "nbS1-O1-vSub-sCN-HEX0-L6-01")),

                            # Hippocampus
                            # obi.NamedPath(name="rCA1-CYLINDER-REF-1PC-8PV-01", path=str(input_root / "rCA1-CYLINDER-REF-1PC-8PV-01")),
                            # obi.NamedPath(name="rCA1-CYLINDER-REF-1PC-8PV-02", path=str(input_root / "rCA1-CYLINDER-REF-1PC-8PV-02")),
                            # obi.NamedPath(name="rCA1-CYLINDER-REF-1PC-8PV-03", path=str(input_root / "rCA1-CYLINDER-REF-1PC-8PV-03")),
                            # obi.NamedPath(name="rCA1-CYLINDER-REF-1PC-8PV-04", path=str(input_root / "rCA1-CYLINDER-REF-1PC-8PV-04")),
                            # obi.NamedPath(name="rCA1-CYLINDER-REF-1PC-8PV-05", path=str(input_root / "rCA1-CYLINDER-REF-1PC-8PV-05")),
                            # obi.NamedPath(name="rCA1-CYLINDER-REF-1PC-8PV-06", path=str(input_root / "rCA1-CYLINDER-REF-1PC-8PV-06")),
                            # obi.NamedPath(name="rCA1-CYLINDER-REF-1PC-8PV-07", path=str(input_root / "rCA1-CYLINDER-REF-1PC-8PV-07")),
                            # obi.NamedPath(name="rCA1-CYLINDER-REF-1PC-8PV-08", path=str(input_root / "rCA1-CYLINDER-REF-1PC-8PV-08")),
                            # obi.NamedPath(name="rCA1-CYLINDER-REF-1PC-8PV-09", path=str(input_root / "rCA1-CYLINDER-REF-1PC-8PV-09")),
                            # obi.NamedPath(name="rCA1-CYLINDER-REF-1PC-8PV-10", path=str(input_root / "rCA1-CYLINDER-REF-1PC-8PV-10")),

                            # Simplex
                            # obi.NamedPath(name="nbS1-O1-sSub-post-dim2-nCN-HEX0-L1-01", path=str(input_root / "nbS1-O1-sSub-post-dim2-nCN-HEX0-L1-01")),
                            # obi.NamedPath(name="nbS1-O1-sSub-post-dim2-nCN-HEX0-L2-01", path=str(input_root / "nbS1-O1-sSub-post-dim2-nCN-HEX0-L2-01")),
                            # obi.NamedPath(name="nbS1-O1-sSub-post-dim2-nCN-HEX0-L3-01", path=str(input_root / "nbS1-O1-sSub-post-dim2-nCN-HEX0-L3-01")),
                            # obi.NamedPath(name="nbS1-O1-sSub-post-dim2-nCN-HEX0-L4-01", path=str(input_root / "nbS1-O1-sSub-post-dim2-nCN-HEX0-L4-01")),
                            # obi.NamedPath(name="nbS1-O1-sSub-post-dim2-nCN-HEX0-L5-01", path=str(input_root / "nbS1-O1-sSub-post-dim2-nCN-HEX0-L5-01")),
                            # obi.NamedPath(name="nbS1-O1-sSub-post-dim2-nCN-HEX0-L6-01", path=str(input_root / "nbS1-O1-sSub-post-dim2-nCN-HEX0-L6-01")),

                            # obi.NamedPath(name="nbS1-O1-sSub-pre-dim2-nCN-HEX0-L1-01", path=str(input_root / "nbS1-O1-sSub-pre-dim2-nCN-HEX0-L1-01")),
                            # obi.NamedPath(name="nbS1-O1-sSub-pre-dim2-nCN-HEX0-L2-01", path=str(input_root / "nbS1-O1-sSub-pre-dim2-nCN-HEX0-L2-01")),
                            # obi.NamedPath(name="nbS1-O1-sSub-pre-dim2-nCN-HEX0-L3-01", path=str(input_root / "nbS1-O1-sSub-pre-dim2-nCN-HEX0-L3-01")),
                            # obi.NamedPath(name="nbS1-O1-sSub-pre-dim2-nCN-HEX0-L4-01", path=str(input_root / "nbS1-O1-sSub-pre-dim2-nCN-HEX0-L4-01")),
                            # obi.NamedPath(name="nbS1-O1-sSub-pre-dim2-nCN-HEX0-L5-01", path=str(input_root / "nbS1-O1-sSub-pre-dim2-nCN-HEX0-L5-01")),
                            # obi.NamedPath(name="nbS1-O1-sSub-pre-dim2-nCN-HEX0-L6-01", path=str(input_root / "nbS1-O1-sSub-pre-dim2-nCN-HEX0-L6-01")),

                            # obi.NamedPath(name="nbS1-O1-sSub-post-dim5-nCN-HEX0-L1-01", path=str(input_root / "nbS1-O1-sSub-post-dim5-nCN-HEX0-L1-01")),
                            # obi.NamedPath(name="nbS1-O1-sSub-post-dim6-nCN-HEX0-L2-01", path=str(input_root / "nbS1-O1-sSub-post-dim6-nCN-HEX0-L2-01")),
                            # obi.NamedPath(name="nbS1-O1-sSub-post-dim6-nCN-HEX0-L3-01", path=str(input_root / "nbS1-O1-sSub-post-dim6-nCN-HEX0-L3-01")),
                            # obi.NamedPath(name="nbS1-O1-sSub-post-dim5-nCN-HEX0-L4-01", path=str(input_root / "nbS1-O1-sSub-post-dim5-nCN-HEX0-L4-01")),
                            # obi.NamedPath(name="nbS1-O1-sSub-post-dim5-nCN-HEX0-L5-01", path=str(input_root / "nbS1-O1-sSub-post-dim5-nCN-HEX0-L5-01")),
                            # obi.NamedPath(name="nbS1-O1-sSub-post-dim6-nCN-HEX0-L6-01", path=str(input_root / "nbS1-O1-sSub-post-dim6-nCN-HEX0-L6-01")),

                            # obi.NamedPath(name="nbS1-O1-sSub-pre-dim5-nCN-HEX0-L1-01", path=str(input_root / "nbS1-O1-sSub-pre-dim5-nCN-HEX0-L1-01")),
                            # obi.NamedPath(name="nbS1-O1-sSub-pre-dim4-nCN-HEX0-L2-01", path=str(input_root / "nbS1-O1-sSub-pre-dim4-nCN-HEX0-L2-01")),
                            # obi.NamedPath(name="nbS1-O1-sSub-pre-dim4-nCN-HEX0-L3-01", path=str(input_root / "nbS1-O1-sSub-pre-dim4-nCN-HEX0-L3-01")),
                            # obi.NamedPath(name="nbS1-O1-sSub-pre-dim5-nCN-HEX0-L4-01", path=str(input_root / "nbS1-O1-sSub-pre-dim5-nCN-HEX0-L4-01")),
                            # obi.NamedPath(name="nbS1-O1-sSub-pre-dim6-nCN-HEX0-L5-01", path=str(input_root / "nbS1-O1-sSub-pre-dim6-nCN-HEX0-L5-01")),
                            # obi.NamedPath(name="nbS1-O1-sSub-pre-dim5-nCN-HEX0-L6-01", path=str(input_root / "nbS1-O1-sSub-pre-dim5-nCN-HEX0-L6-01")),

                            # Pairs
                            obi.NamedPath(name="nbS1-O1-E2PV-maxNsyn-HEX0-L2", path=str(input_root / "nbS1-O1-E2PV-maxNsyn-HEX0-L2")),
                            obi.NamedPath(name="nbS1-O1-E2Sst-maxNsyn-HEX0-L2", path=str(input_root / "nbS1-O1-E2Sst-maxNsyn-HEX0-L2")),
                            obi.NamedPath(name="nbS1-O1-E2PV-maxNsyn-HEX0-L3", path=str(input_root / "nbS1-O1-E2PV-maxNsyn-HEX0-L3")),
                            obi.NamedPath(name="nbS1-O1-E2Sst-maxNsyn-HEX0-L3", path=str(input_root / "nbS1-O1-E2Sst-maxNsyn-HEX0-L3")),
                            obi.NamedPath(name="nbS1-O1-E2PV-maxNsyn-HEX0-L4", path=str(input_root / "nbS1-O1-E2PV-maxNsyn-HEX0-L4")),
                            obi.NamedPath(name="nbS1-O1-E2Sst-maxNsyn-HEX0-L4", path=str(input_root / "nbS1-O1-E2Sst-maxNsyn-HEX0-L4")),
                            obi.NamedPath(name="nbS1-O1-E2PV-maxNsyn-HEX0-L5", path=str(input_root / "nbS1-O1-E2PV-maxNsyn-HEX0-L5")),
                            obi.NamedPath(name="nbS1-O1-E2Sst-maxNsyn-HEX0-L5", path=str(input_root / "nbS1-O1-E2Sst-maxNsyn-HEX0-L5")),
                            obi.NamedPath(name="nbS1-O1-E2PV-maxNsyn-HEX0-L6", path=str(input_root / "nbS1-O1-E2PV-maxNsyn-HEX0-L6")),
                            obi.NamedPath(name="nbS1-O1-E2Sst-maxNsyn-HEX0-L6", path=str(input_root / "nbS1-O1-E2Sst-maxNsyn-HEX0-L6")),

                            obi.NamedPath(name="nbS1-O1-PV2E-maxNsyn-HEX0-L2", path=str(input_root / "nbS1-O1-PV2E-maxNsyn-HEX0-L2")),
                            obi.NamedPath(name="nbS1-O1-Sst2E-maxNsyn-HEX0-L2", path=str(input_root / "nbS1-O1-Sst2E-maxNsyn-HEX0-L2")),
                            obi.NamedPath(name="nbS1-O1-PV2E-maxNsyn-HEX0-L3", path=str(input_root / "nbS1-O1-PV2E-maxNsyn-HEX0-L3")),
                            obi.NamedPath(name="nbS1-O1-Sst2E-maxNsyn-HEX0-L3", path=str(input_root / "nbS1-O1-Sst2E-maxNsyn-HEX0-L3")),
                            obi.NamedPath(name="nbS1-O1-PV2E-maxNsyn-HEX0-L4", path=str(input_root / "nbS1-O1-PV2E-maxNsyn-HEX0-L4")),
                            obi.NamedPath(name="nbS1-O1-Sst2E-maxNsyn-HEX0-L4", path=str(input_root / "nbS1-O1-Sst2E-maxNsyn-HEX0-L4")),
                            obi.NamedPath(name="nbS1-O1-PV2E-maxNsyn-HEX0-L5", path=str(input_root / "nbS1-O1-PV2E-maxNsyn-HEX0-L5")),
                            obi.NamedPath(name="nbS1-O1-Sst2E-maxNsyn-HEX0-L5", path=str(input_root / "nbS1-O1-Sst2E-maxNsyn-HEX0-L5")),
                            obi.NamedPath(name="nbS1-O1-PV2E-maxNsyn-HEX0-L6", path=str(input_root / "nbS1-O1-PV2E-maxNsyn-HEX0-L6")),
                            obi.NamedPath(name="nbS1-O1-Sst2E-maxNsyn-HEX0-L6", path=str(input_root / "nbS1-O1-Sst2E-maxNsyn-HEX0-L6")),

                            obi.NamedPath(name="nbS1-O1-ErcPV-maxNsyn-HEX0-L2", path=str(input_root / "nbS1-O1-ErcPV-maxNsyn-HEX0-L2")),
                            obi.NamedPath(name="nbS1-O1-ErcSst-maxNsyn-HEX0-L2", path=str(input_root / "nbS1-O1-ErcSst-maxNsyn-HEX0-L2")),
                            obi.NamedPath(name="nbS1-O1-ErcPV-maxNsyn-HEX0-L3", path=str(input_root / "nbS1-O1-ErcPV-maxNsyn-HEX0-L3")),
                            obi.NamedPath(name="nbS1-O1-ErcSst-maxNsyn-HEX0-L3", path=str(input_root / "nbS1-O1-ErcSst-maxNsyn-HEX0-L3")),
                            obi.NamedPath(name="nbS1-O1-ErcPV-maxNsyn-HEX0-L4", path=str(input_root / "nbS1-O1-ErcPV-maxNsyn-HEX0-L4")),
                            obi.NamedPath(name="nbS1-O1-ErcSst-maxNsyn-HEX0-L4", path=str(input_root / "nbS1-O1-ErcSst-maxNsyn-HEX0-L4")),
                            obi.NamedPath(name="nbS1-O1-ErcPV-maxNsyn-HEX0-L5", path=str(input_root / "nbS1-O1-ErcPV-maxNsyn-HEX0-L5")),
                            obi.NamedPath(name="nbS1-O1-ErcSst-maxNsyn-HEX0-L5", path=str(input_root / "nbS1-O1-ErcSst-maxNsyn-HEX0-L5")),
                            obi.NamedPath(name="nbS1-O1-ErcPV-maxNsyn-HEX0-L6", path=str(input_root / "nbS1-O1-ErcPV-maxNsyn-HEX0-L6")),
                            obi.NamedPath(name="nbS1-O1-ErcSst-maxNsyn-HEX0-L6", path=str(input_root / "nbS1-O1-ErcSst-maxNsyn-HEX0-L6")),
                        ],
                        file_format="gz",
                        file_name="circuit"
                    )
)

grid_scan = obi.GridScanGenerationTask(form=folder_compressions_scan_config, output_root=output_root, coordinate_directory_option="VALUE")

# %%
grid_scan.execute()
obi.run_tasks_for_generated_scan(grid_scan)
# Out:
# [2025-06-23 17:06:06,844] INFO: None
# [2025-06-23 17:06:06,859] INFO: Info: Running gz compression on 'nbS1-O1-E2PV-maxNsyn-HEX0-L2'...
# [2025-06-23 17:06:07,280] INFO: DONE (Duration 00h:00min:00s; File size 1.8MB)
# [2025-06-23 17:06:07,281] INFO: Info: Running gz compression on 'nbS1-O1-E2Sst-maxNsyn-HEX0-L2'...
# [2025-06-23 17:06:07,469] INFO: DONE (Duration 00h:00min:00s; File size 0.8MB)
# [2025-06-23 17:06:07,470] INFO: Info: Running gz compression on 'nbS1-O1-E2PV-maxNsyn-HEX0-L3'...
# [2025-06-23 17:06:07,771] INFO: DONE (Duration 00h:00min:00s; File size 1.3MB)
# [2025-06-23 17:06:07,772] INFO: Info: Running gz compression on 'nbS1-O1-E2Sst-maxNsyn-HEX0-L3'...
# [2025-06-23 17:06:08,108] INFO: DONE (Duration 00h:00min:00s; File size 1.4MB)
# [2025-06-23 17:06:08,109] INFO: Info: Running gz compression on 'nbS1-O1-E2PV-maxNsyn-HEX0-L4'...
# [2025-06-23 17:06:08,378] INFO: DONE (Duration 00h:00min:00s; File size 1.1MB)
# ...
