# %% [markdown]
# ## Check mod files

# %%
import obi_one as obi
import os

# %%
ref_counts = {"nbS1": 28, "rCA1": 30}

# %%
# # Local folders
# circuit_folders = [
#     "../../../obi-output/decontainerized_small_microcircuits_volumetric/nbS1-O1-vSub-nCN-HEX0-L1-01",
#     "../../../obi-output/decontainerized_small_microcircuits_volumetric/nbS1-O1-vSub-nCN-HEX0-L2-01",
#     "../../../obi-output/decontainerized_small_microcircuits_volumetric/nbS1-O1-vSub-nCN-HEX0-L3-01",
#     "../../../obi-output/decontainerized_small_microcircuits_volumetric/nbS1-O1-vSub-nCN-HEX0-L4-01",
#     "../../../obi-output/decontainerized_small_microcircuits_volumetric/nbS1-O1-vSub-nCN-HEX0-L5-01",
#     "../../../obi-output/decontainerized_small_microcircuits_volumetric/nbS1-O1-vSub-nCN-HEX0-L6-01",

#     "../../../obi-output/decontainerized_small_microcircuits_volumetric/nbS1-O1-vSub-sCN-HEX0-L1-01",
#     "../../../obi-output/decontainerized_small_microcircuits_volumetric/nbS1-O1-vSub-sCN-HEX0-L2-01",
#     "../../../obi-output/decontainerized_small_microcircuits_volumetric/nbS1-O1-vSub-sCN-HEX0-L3-01",
#     "../../../obi-output/decontainerized_small_microcircuits_volumetric/nbS1-O1-vSub-sCN-HEX0-L4-01",
#     "../../../obi-output/decontainerized_small_microcircuits_volumetric/nbS1-O1-vSub-sCN-HEX0-L5-01",
#     "../../../obi-output/decontainerized_small_microcircuits_volumetric/nbS1-O1-vSub-sCN-HEX0-L6-01",

#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-post-dim2-nCN-HEX0-L1-01",
#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-post-dim2-nCN-HEX0-L2-01",
#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-post-dim2-nCN-HEX0-L3-01",
#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-post-dim2-nCN-HEX0-L4-01",
#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-post-dim2-nCN-HEX0-L5-01",
#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-post-dim2-nCN-HEX0-L6-01",

#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-pre-dim2-nCN-HEX0-L1-01",
#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-pre-dim2-nCN-HEX0-L2-01",
#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-pre-dim2-nCN-HEX0-L3-01",
#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-pre-dim2-nCN-HEX0-L4-01",
#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-pre-dim2-nCN-HEX0-L5-01",
#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-pre-dim2-nCN-HEX0-L6-01",

#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-post-dim5-nCN-HEX0-L1-01",
#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-post-dim6-nCN-HEX0-L2-01",
#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-post-dim6-nCN-HEX0-L3-01",
#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-post-dim5-nCN-HEX0-L4-01",
#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-post-dim5-nCN-HEX0-L5-01",
#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-post-dim6-nCN-HEX0-L6-01",

#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-pre-dim5-nCN-HEX0-L1-01",
#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-pre-dim4-nCN-HEX0-L2-01",
#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-pre-dim4-nCN-HEX0-L3-01",
#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-pre-dim5-nCN-HEX0-L4-01",
#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-pre-dim6-nCN-HEX0-L5-01",
#     "../../../obi-output/decontainerized_small_microcircuits_simplex/nbS1-O1-sSub-pre-dim5-nCN-HEX0-L6-01",

#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-E2PV-maxNsyn-HEX0-L2",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-E2PV-maxNsyn-HEX0-L3",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-E2PV-maxNsyn-HEX0-L4",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-E2PV-maxNsyn-HEX0-L5",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-E2PV-maxNsyn-HEX0-L6",
    
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-E2Sst-maxNsyn-HEX0-L2",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-E2Sst-maxNsyn-HEX0-L3",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-E2Sst-maxNsyn-HEX0-L4",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-E2Sst-maxNsyn-HEX0-L5",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-E2Sst-maxNsyn-HEX0-L6",

#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-PV2E-maxNsyn-HEX0-L2",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-PV2E-maxNsyn-HEX0-L3",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-PV2E-maxNsyn-HEX0-L4",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-PV2E-maxNsyn-HEX0-L5",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-PV2E-maxNsyn-HEX0-L6",
    
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-Sst2E-maxNsyn-HEX0-L2",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-Sst2E-maxNsyn-HEX0-L3",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-Sst2E-maxNsyn-HEX0-L4",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-Sst2E-maxNsyn-HEX0-L5",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-Sst2E-maxNsyn-HEX0-L6",

#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-ErcPV-maxNsyn-HEX0-L2",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-ErcPV-maxNsyn-HEX0-L3",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-ErcPV-maxNsyn-HEX0-L4",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-ErcPV-maxNsyn-HEX0-L5",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-ErcPV-maxNsyn-HEX0-L6",

#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-ErcSst-maxNsyn-HEX0-L2",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-ErcSst-maxNsyn-HEX0-L3",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-ErcSst-maxNsyn-HEX0-L4",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-ErcSst-maxNsyn-HEX0-L5",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-ErcSst-maxNsyn-HEX0-L6",
    
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/rCA1-CYLINDER-REF-1PC-8PV-01",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/rCA1-CYLINDER-REF-1PC-8PV-02",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/rCA1-CYLINDER-REF-1PC-8PV-03",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/rCA1-CYLINDER-REF-1PC-8PV-04",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/rCA1-CYLINDER-REF-1PC-8PV-05",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/rCA1-CYLINDER-REF-1PC-8PV-06",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/rCA1-CYLINDER-REF-1PC-8PV-07",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/rCA1-CYLINDER-REF-1PC-8PV-08",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/rCA1-CYLINDER-REF-1PC-8PV-09",
#     "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/rCA1-CYLINDER-REF-1PC-8PV-10",
# ]

# %%
# OneDrive folders
circuit_folders = [
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-vSub-nCN-HEX0-L1-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-vSub-nCN-HEX0-L2-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-vSub-nCN-HEX0-L3-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-vSub-nCN-HEX0-L4-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-vSub-nCN-HEX0-L5-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-vSub-nCN-HEX0-L6-01",

    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-vSub-sCN-HEX0-L1-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-vSub-sCN-HEX0-L2-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-vSub-sCN-HEX0-L3-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-vSub-sCN-HEX0-L4-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-vSub-sCN-HEX0-L5-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-vSub-sCN-HEX0-L6-01",

    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-post-dim2-nCN-HEX0-L1-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-post-dim2-nCN-HEX0-L2-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-post-dim2-nCN-HEX0-L3-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-post-dim2-nCN-HEX0-L4-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-post-dim2-nCN-HEX0-L5-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-post-dim2-nCN-HEX0-L6-01",

    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-pre-dim2-nCN-HEX0-L1-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-pre-dim2-nCN-HEX0-L2-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-pre-dim2-nCN-HEX0-L3-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-pre-dim2-nCN-HEX0-L4-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-pre-dim2-nCN-HEX0-L5-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-pre-dim2-nCN-HEX0-L6-01",

    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-post-dim5-nCN-HEX0-L1-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-post-dim6-nCN-HEX0-L2-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-post-dim6-nCN-HEX0-L3-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-post-dim5-nCN-HEX0-L4-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-post-dim5-nCN-HEX0-L5-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-post-dim6-nCN-HEX0-L6-01",

    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-pre-dim5-nCN-HEX0-L1-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-pre-dim4-nCN-HEX0-L2-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-pre-dim4-nCN-HEX0-L3-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-pre-dim5-nCN-HEX0-L4-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-pre-dim6-nCN-HEX0-L5-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-sSub-pre-dim5-nCN-HEX0-L6-01",

    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-E2PV-maxNsyn-HEX0-L2",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-E2PV-maxNsyn-HEX0-L3",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-E2PV-maxNsyn-HEX0-L4",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-E2PV-maxNsyn-HEX0-L5",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-E2PV-maxNsyn-HEX0-L6",
    
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-E2Sst-maxNsyn-HEX0-L2",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-E2Sst-maxNsyn-HEX0-L3",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-E2Sst-maxNsyn-HEX0-L4",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-E2Sst-maxNsyn-HEX0-L5",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-E2Sst-maxNsyn-HEX0-L6",

    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-PV2E-maxNsyn-HEX0-L2",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-PV2E-maxNsyn-HEX0-L3",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-PV2E-maxNsyn-HEX0-L4",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-PV2E-maxNsyn-HEX0-L5",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-PV2E-maxNsyn-HEX0-L6",
    
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-Sst2E-maxNsyn-HEX0-L2",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-Sst2E-maxNsyn-HEX0-L3",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-Sst2E-maxNsyn-HEX0-L4",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-Sst2E-maxNsyn-HEX0-L5",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-Sst2E-maxNsyn-HEX0-L6",

    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-ErcPV-maxNsyn-HEX0-L2",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-ErcPV-maxNsyn-HEX0-L3",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-ErcPV-maxNsyn-HEX0-L4",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-ErcPV-maxNsyn-HEX0-L5",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-ErcPV-maxNsyn-HEX0-L6",

    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-ErcSst-maxNsyn-HEX0-L2",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-ErcSst-maxNsyn-HEX0-L3",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-ErcSst-maxNsyn-HEX0-L4",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-ErcSst-maxNsyn-HEX0-L5",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/nbS1-O1-ErcSst-maxNsyn-HEX0-L6",
    
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/rCA1-CYLINDER-REF-1PC-8PV-01",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/rCA1-CYLINDER-REF-1PC-8PV-02",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/rCA1-CYLINDER-REF-1PC-8PV-03",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/rCA1-CYLINDER-REF-1PC-8PV-04",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/rCA1-CYLINDER-REF-1PC-8PV-05",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/rCA1-CYLINDER-REF-1PC-8PV-06",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/rCA1-CYLINDER-REF-1PC-8PV-07",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/rCA1-CYLINDER-REF-1PC-8PV-08",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/rCA1-CYLINDER-REF-1PC-8PV-09",
    "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Circuits/rCA1-CYLINDER-REF-1PC-8PV-10",
]

# %%
for _idx, _cpath in enumerate(circuit_folders):
    _files = os.listdir(os.path.join(_cpath, "mod"))
    _name = os.path.split(_cpath)[-1]
    print(f"{_idx:2d}: {_name} - {len(_files)} mod files")
    for _k, _v in ref_counts.items():
        if _k in _name:
            assert len(_files) == _v, "ERROR: Count mismatch!"
# Out:
#  0: nbS1-O1-vSub-nCN-HEX0-L1-01 - 28 mod files
#  1: nbS1-O1-vSub-nCN-HEX0-L2-01 - 28 mod files
#  2: nbS1-O1-vSub-nCN-HEX0-L3-01 - 28 mod files
#  3: nbS1-O1-vSub-nCN-HEX0-L4-01 - 28 mod files
#  4: nbS1-O1-vSub-nCN-HEX0-L5-01 - 28 mod files
#  5: nbS1-O1-vSub-nCN-HEX0-L6-01 - 28 mod files
#  6: nbS1-O1-vSub-sCN-HEX0-L1-01 - 28 mod files
#  7: nbS1-O1-vSub-sCN-HEX0-L2-01 - 28 mod files
#  8: nbS1-O1-vSub-sCN-HEX0-L3-01 - 28 mod files
#  9: nbS1-O1-vSub-sCN-HEX0-L4-01 - 28 mod files
# 10: nbS1-O1-vSub-sCN-HEX0-L5-01 - 28 mod files
# 11: nbS1-O1-vSub-sCN-HEX0-L6-01 - 28 mod files
# 12: nbS1-O1-sSub-post-dim2-nCN-HEX0-L1-01 - 28 mod files
# 13: nbS1-O1-sSub-post-dim2-nCN-HEX0-L2-01 - 28 mod files
# 14: nbS1-O1-sSub-post-dim2-nCN-HEX0-L3-01 - 28 mod files
# 15: nbS1-O1-sSub-post-dim2-nCN-HEX0-L4-01 - 28 mod files
# 16: nbS1-O1-sSub-post-dim2-nCN-HEX0-L5-01 - 28 mod files
# 17: nbS1-O1-sSub-post-dim2-nCN-HEX0-L6-01 - 28 mod files
# 18: nbS1-O1-sSub-pre-dim2-nCN-HEX0-L1-01 - 28 mod files
# ...
