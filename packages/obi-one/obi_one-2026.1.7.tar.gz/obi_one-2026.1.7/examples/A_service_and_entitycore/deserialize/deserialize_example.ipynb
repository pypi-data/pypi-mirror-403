# %% [markdown]
# This notebooks shows how to deserialize:
# 1) a grid scan
# 2) a single coordinate in a grid scan
#
#
# First create a grid scan locally using one of the other notebooks

# %%
import obi_one as obi

grid_scan = obi.deserialize_obi_object_from_json_file("../../../../obi-output/circuit_simulations/grid_scan/obi_one_scan.json")
simulation = obi.deserialize_obi_object_from_json_file("../../../../obi-output/circuit_simulations/grid_scan/0/obi_one_coordinate.json")
