# %%
import dotenv

import babamul

dotenv.load_dotenv()

# %%
# Get your user profile
babamul.api.get_current_user()

# %%
# Search for alerts
alerts = babamul.api.get_alerts(
    survey="lsst", ra=83.6331, dec=22.0145, radius_arcsec=0.1
)
